# %%
import re
from gensim import corpora, models
from nltk.corpus import stopwords
from string import punctuation
from nltk.tokenize import word_tokenize
import string
import seaborn as sns
import matplotlib.pyplot as plt
import pyLDAvis.gensim
import pandas as pd
from collections import OrderedDict

#HappyEmoticons
emoticons_happy = set([
    ':-)', ':)', ';)', ':o)', ':]', ':3', ':c)', ':>', '=]', '8)', '=)', ':}',
    ':^)', ':-D', ':D', '8-D', '8D', 'x-D', 'xD', 'X-D', 'XD', '=-D', '=D',
    '=-3', '=3', ':-))', ":'-)", ":')", ':*', ':^*', '>:P', ':-P', ':P', 'X-P',
    'x-p', 'xp', 'XP', ':-p', ':p', '=p', ':-b', ':b', '>:)', '>;)', '>:-)',
    '<3'
    ])

# Sad Emoticons
emoticons_sad = set([
    ':L', ':-/', '>:/', ':S', '>:[', ':@', ':-(', ':[', ':-||', '=L', ':<',
    ':-[', ':-<', '=\\', '=/', '>:(', ':(', '>.<', ":'-(", ":'(", ':\\', ':-c',
    ':c', ':{', '>:\\', ';('
    ])

emoticons = emoticons_happy.union(emoticons_sad)

emoji_pattern = re.compile("["
         u"\U0001F600-\U0001F64F"  # emoticons
         u"\U0001F300-\U0001F5FF"  # symbols & pictographs
         u"\U0001F680-\U0001F6FF"  # transport & map symbols
         u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
         u"\U00002702-\U000027B0"
         u"\U000024C2-\U0001F251"
         "]+", flags = re.UNICODE)


def corpus_prep(tweets):
    # Changing &amp; to 'and'
    tweets = list(map(lambda x: re.sub(u'&amp;', u'and', x), tweets))
    # extracting URLS
    tweets = list(map(lambda x: re.sub(u'http\\S+', u'', x), tweets))
    # replacing — with a space
    tweets = list(map(lambda x: re.sub(u'\—', u' ', x), tweets))
    return tweets

def clean_tweets(tweet):
    stop_words = set(stopwords.words('english') + list(punctuation) + ['RT','rt'])
    word_tokens = word_tokenize(tweet)
    #after tweepy preprocessing the colon symbol left remain after      #removing mentions
    tweet = re.sub(r'\&amp\;', 'and', tweet)
    tweet = re.sub(r':', '', tweet)
    tweet = re.sub(r'‚Ä¶', '', tweet)
    #replace consecutive non-ASCII characters with a space
    tweet = re.sub(r'[^\x00-\x7F]+',' ', tweet)
    #remove emojis from tweet
    tweet = emoji_pattern.sub(r'', tweet)
    #filter using NLTK library append it to a string
    filtered_tweet = [w for w in word_tokens if not w in stop_words]
    filtered_tweet = []
    #looping through conditions
    for w in word_tokens:
    #check tokens against stop words , emoticons and punctuations
        if w not in stop_words and w not in emoticons and w not in string.punctuation:
            filtered_tweet.append(w)
    return filtered_tweet

def LDA_Analysis(data_list, topics = 5):
    data_list = corpus_prep(data_list)
    texts = [[word for word in clean_tweets(str(document).lower())] for document in data_list]
    dictionary = corpora.Dictionary(texts)
    
    corpus = [dictionary.doc2bow(text) for text in texts]
    tfidf = models.TfidfModel(corpus) 
    corpus_tfidf = tfidf[corpus] 
    
    lda = models.LdaMulticore(corpus, id2word = dictionary, num_topics = topics)
    corpus_lda = lda[corpus_tfidf] # create a double wrapper over the original corpus: bow->tfidf->fold-in-lsi
    
    data_lda = {i: OrderedDict(lda.show_topic(i,25)) for i in range(topics)}
    
    df_lda = pd.DataFrame(data_lda)
    df_lda = df_lda.fillna(0).T

    g = sns.clustermap(df_lda.corr(), center = 0, cmap = "RdBu", metric = 'cosine', linewidths = .75, figsize = (12, 12))
    plt.setp(g.ax_heatmap.yaxis.get_majorticklabels(), rotation=0)
    plt.show()

    pyLDAvis.enable_notebook()
    
    panel = pyLDAvis.gensim.prepare(lda, corpus_lda, dictionary, mds = 'tsne')
    
    return panel

# %%
def word_in_text(word, text):
    word = word.lower()
    text = text.lower()
    match = re.search(word, text)
    if match:
        return True
    return False

def word_basket_in_text(word_list, text):
    status = True
    for word in word_list:
        if type(word)==list:
            list_status = False
            for list_word in word:
                list_status = list_status or word_in_text(list_word, text)
            status = status and list_status
        else: status = status and word_in_text(word, text)
    return status

# %%
tweets = get_tweets('ewarren')

military = [['care','affordable', 'medicare', 'obamacare']]

rel_tweet = []
for tweet in tweets['text']:
    if word_basket_in_text(military, tweet):
        rel_tweet.append(tweet)

# %%
rel_tweet
# Out:
# ["I spent a big chunk of my life studying why families go broke, and one of the top reasons is a medical emergency. That's not right. Our system is working for corporations making a profit, but not for families. That's why I'm fighting for #MedicareForAll. #DemDebate https://t.co/MhYfR235nG",
#  "RT @TeamWarren: Our health care system is working great for companies making massive profits, but not for families who can't afford health…",
#  'Women’s rights are human rights. We need to:\n\n✔ Protect #RoeVWade.\n✔ End the #HydeAmendment.\n✔ Defend #TitleX family planning funding.\n✔ Ensure that #MedicareForAll includes contraception and abortion coverage.\n\nhttps://t.co/iBzvjDBCL4\n\n#DemDebate',
#  "RT @TeamWarren: Health care is a basic human right, and @ewarren will fight for basic human rights. She's fighting for #MedicareForAll. #De…",
# ...

# %%
LDA_Analysis(rel_tweet, topics = 3)
# Out:
# 2019-07-04 16:29:11,416 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2019-07-04 16:29:11,427 : INFO : built Dictionary(1818 unique tokens: ["'m", "'s", 'big', 'broke', 'chunk']...) from 300 documents (total 6232 corpus positions)
# 2019-07-04 16:29:11,435 : INFO : collecting document frequencies
# 2019-07-04 16:29:11,436 : INFO : PROGRESS: processing document #0
# 2019-07-04 16:29:11,442 : INFO : calculating IDF weights for 300 documents and 1818 features (5822 matrix non-zeros)
# 2019-07-04 16:29:11,449 : INFO : using symmetric alpha at 0.3333333333333333
# 2019-07-04 16:29:11,450 : INFO : using symmetric eta at 0.3333333333333333
# 2019-07-04 16:29:11,452 : INFO : using serial LDA version on this node
# 2019-07-04 16:29:11,456 : INFO : running online LDA training, 3 topics, 1 passes over the supplied corpus of 300 documents, updating every 6000 documents, evaluating every ~300 documents, iterating 50x with a convergence threshold of 0.001000
# ...
