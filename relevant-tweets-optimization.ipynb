# %%
% matplotlib inline

from __future__ import division

import numpy as np 
import pandas as pd 

import spacy
from spacy.tokens.doc import Doc
import inspect

from textacy.vsm import Vectorizer
import textacy.vsm

import scipy.sparse as sp

from tqdm import *

import re
import en_core_web_sm

# %% [markdown]
# ### Loading Data

# %%
def get_tweets(name):
    tweet_data = pd.read_csv('Tweets//'+name+'_tweets.csv', encoding = 'utf-8')
    return tweet_data

# %%
tweets = get_tweets('ewarren')
tweets = tweets.dropna()

# %% [markdown]
# ### Pre-processing Data

# %%
# extracting URLS
tweets['urls'] = tweets.text.apply(lambda x: re.findall('http\S+', x))
tweets['text_clean'] = tweets.text.apply(lambda x: re.sub(u'http\S+', u'', x)) 

# extracting @... 
tweets['mentions'] = tweets.text.apply(lambda x: re.findall(u'@(\w+)', x))
tweets.text_clean = tweets.text_clean.apply(lambda x: re.sub(u'@(\w+)', u'', x))

# extracting hashtags
tweets['hashtags'] = tweets.text.apply(lambda x: re.findall(u'#(\w+)', x))
tweets.text_clean = tweets.text_clean.apply(lambda x: re.sub(u'#', u'', x))

# Binary for Re-Tweets
tweets['retweet'] = tweets.text.apply(lambda x: 1 if len(re.findall(u'RT', x))>0 else 0)
tweets.text_clean = tweets.text_clean.apply(lambda x: re.sub(u'RT', u'', x))

# %%
tweets
# Out:
#                        id           created_at  \
# 0     1144276520875319296  2019-06-27 16:09:16
# 1     1144276520090918913  2019-06-27 16:09:16
# 2     1144276518786555906  2019-06-27 16:09:16
# 3     1144237476451639296  2019-06-27 13:34:07
# 4     1144088262174228480  2019-06-27 03:41:12
# 5     1144086118465515520  2019-06-27 03:32:41
# 6     1144082731745366016  2019-06-27 03:19:13
# 7     1144080356729118721  2019-06-27 03:09:47
# 8     1144079755987341312  2019-06-27 03:07:24
# 9     1144074674898382848  2019-06-27 02:47:13
# 10    1144073763279032320  2019-06-27 02:43:35
# 11    1144071973724704769  2019-06-27 02:36:29
# 12    1144071873149509633  2019-06-27 02:36:05
# 13    1144069425164881921  2019-06-27 02:26:21
# 14    1144068693288194048  2019-06-27 02:23:26
# 15    1144066036557389829  2019-06-27 02:12:53
# 16    1144062449005600768  2019-06-27 01:58:38
# 17    1144060533395664896  2019-06-27 01:51:01
# 18    1144059197568561154  2019-06-27 01:45:42
# 19    1144059064764305408  2019-06-27 01:45:11
# 20    1144058026325884934  2019-06-27 01:41:03
# 21    1144056591957876737  2019-06-27 01:35:21
# 22    1144055747283685376  2019-06-27 01:32:00
# 23    1144055312124657665  2019-06-27 01:30:16
# 24    1144055120109494273  2019-06-27 01:29:30
# 25    1144055079416336384  2019-06-27 01:29:21
# 26    1144054259547299850  2019-06-27 01:26:05
# 27    1144054071776763904  2019-06-27 01:25:20
# 28    1144053575410208768  2019-06-27 01:23:22
# 29    1144053167128219653  2019-06-27 01:21:45
# ...                   ...                  ...
# 3170   760277910758494212  2016-08-02 00:55:53
# 3171   760146049969389568  2016-08-01 16:11:55
# 3172   758876815989407746  2016-07-29 04:08:26
# 3173   758872770793000960  2016-07-29 03:52:22
# 3174   758840401297977345  2016-07-29 01:43:44
# 3175   758828216911925248  2016-07-29 00:55:19
# 3176   758825514224070657  2016-07-29 00:44:35
# 3177   758823462454517760  2016-07-29 00:36:26
# 3178   758822277068693504  2016-07-29 00:31:43
# 3179   758821475797217281  2016-07-29 00:28:32
# 3180   758819904770281473  2016-07-29 00:22:18
# 3181   758787671493869568  2016-07-28 22:14:13
# 3182   758507966643527680  2016-07-28 03:42:46
# 3183   758407912624627712  2016-07-27 21:05:11
# 3184   758382963524501504  2016-07-27 19:26:03
# 3185   758073466167955456  2016-07-26 22:56:13
# 3186   758043325836451841  2016-07-26 20:56:27
# 3187   757943172861456384  2016-07-26 14:18:28
# 3188   757768777631170560  2016-07-26 02:45:29
# 3189   757762356076216321  2016-07-26 02:19:58
# 3190   757743328314130432  2016-07-26 01:04:22
# 3191   757741292155703296  2016-07-26 00:56:16
# 3192   757738958826704896  2016-07-26 00:47:00
# 3193   757681061291626496  2016-07-25 20:56:56
# 3194   757610159048974336  2016-07-25 16:15:12
# 3195   757370297788030976  2016-07-25 00:22:04
# 3196   756992880984469504  2016-07-23 23:22:21
# 3197   756992556655742976  2016-07-23 23:21:04
# 3198   756992228023672832  2016-07-23 23:19:46
# 3199   756991867359666176  2016-07-23 23:18:20
#
#                                                    text  \
# 0     I'm done playing by a different set of rules. ...
# 1     Mitch McConnell says efforts to stop gerrymand...
# 2     The Supreme Court's decision is an abomination...
# 3     You bet I have a plan to deal with Mitch McCon...
# 4     The economy is doing great for a thinner and t...
# 5     I spent a big chunk of my life studying why fa...
# 6     RT @TeamWarren: .@ewarren can make our governm...
# 7     I just stepped off the #DemDebate stage. I hav...
# 8     I’m in this fight for a government and an econ...
# 9     No one should be above the law—that includes t...
# 10    The threat posed by climate change is real, it...
# 11    RT @TeamWarren: Yeah—@ewarren even has a plan ...
# 12    We’re fighting for big, structural change to o...
# 13    RT @TeamWarren: Gun violence is a public healt...
# 14    I have a LOT of plans—and you bet I have one t...
# 15    Since running for president, I’ve answered tho...
# 16    As president, I would make sure our country ge...
# 17    I went to the Homestead, FL detention center t...
# 18    RT @TeamWarren: .@ewarren has a plan to protec...
# 19    RT @ewarren: I agree with @JulianCastro: We sh...
# 20    RT @TeamWarren: Our health care system is work...
# 21    Every woman should have access to the full ran...
# 22    Women’s rights are human rights. We need to:\n...
# 23    RT @TeamWarren: Health care is a basic human r...
# 24    RT @TeamWarren: The economy is doing great for...
# 25    RT @TeamWarren: We need courage in Washington ...
# 26    Yes, I would support government-run insurance....
# 27    I’ve spent my life studying why families go br...
# 28    Some politicians say Medicare for All isn’t po...
# 29    As president, I will pursue an agenda of econo...
# ...                                                 ...
# 3170  If you don't think this is how a President Tru...
# 3171  Delighted to have Joanie back on the team. @re...
# 3172  Three generations of celebrating. #ImWithHer #...
# 3173  For my daughter, granddaughters, &amp; for all...
# 3174  Glad to join the Dem women of the Senate on st...
# 3175  Texas has been a terrific neighbor to our MA d...
# 3176  Always a great honor to see Governor Dukakis &...
# 3177  If you think I'm a fighter, you should meet my...
# 3178  The best partner a senator could ask for: my f...
# 3179  Don't tell the other states, but hanging out w...
# 3180  Just finished up a terrific interview with @ka...
# 3181  Getting ready to speak at the #demconvention w...
# 3182  I'm still fired up &amp; ready to go for @Bara...
# 3183  Dem women are going to take back the Senate &a...
# 3184  I love being with the labor council in Philly....
# 3185  .@realDonaldTrump, often referred to as a thin...
# 3186  I had a terrific time talking about what's hap...
# 3187  You didn't like a speech explaining why you'll...
# 3188  Thank you #DemConvention &amp; thank you Ameri...
# 3189  In just a few minutes I’ll take the stage at t...
# 3190  Your speech was terrific, Al! #DemConvention #...
# 3191  Bruce &amp; I are hanging out backstage with @...
# 3192  I've got the best seat in the house: watching ...
# 3193  Tonight I'll be delivering the #demconvention ...
# 3194  Getting ready for my big #demconvention speech...
# 3195  Made it to Philly for #DNCinPHL! 1st stop stra...
# 3196  Today I told #NCLR16 that we’ll never build Tr...
# 3197  .@realDonaldTrump? He cheered on the 2008 hous...
# 3198  .@timkaine started his career helping families...
# 3199  During the 2008 crash, Latino families were 71...
#
#                            urls  \
# 0     [https://t.co/WV0BqmmKjU]
# 1                            []
# 2                            []
# 3     [https://t.co/X0ODfTwoRy]
# 4     [https://t.co/8oBa9a4TmB]
# 5     [https://t.co/MhYfR235nG]
# 6                            []
# 7     [https://t.co/pSUwFnT5qq]
# 8                            []
# 9     [https://t.co/v1pgkcdRDm]
# 10                           []
# 11    [https://t.co/CymR0WfH3F]
# 12                           []
# 13                           []
# 14                           []
# 15                           []
# 16                           []
# 17                           []
# 18             [https://t.co/…]
# 19                           []
# 20                           []
# 21    [https://t.co/iBzvjDBCL4]
# 22    [https://t.co/iBzvjDBCL4]
# 23                           []
# 24                           []
# 25              [https://t.co…]
# 26                           []
# 27                           []
# 28                           []
# 29    [https://t.co/pWxwPq2uV1]
# ...                         ...
# 3170  [https://t.co/BYha5ldJ7J]
# 3171  [https://t.co/4qjn0DgQ59]
# 3172  [https://t.co/UkCHFWLO7l]
# 3173                         []
# 3174  [https://t.co/Ao4S6DIHoE]
# 3175  [https://t.co/5yB9bRZG7x]
# 3176  [https://t.co/SCrMwO8Og3]
# 3177  [https://t.co/IMapQuQo5h]
# 3178  [https://t.co/Z6KtNsrBbo]
# 3179  [https://t.co/hs8EFg2hj5]
# 3180  [https://t.co/yHegE04xWd]
# 3181  [https://t.co/AfEg6YXUH8]
# 3182                         []
# 3183  [https://t.co/nAPKANGWdB]
# 3184  [https://t.co/NyOvad757u]
# 3185                         []
# 3186  [https://t.co/llw7lUJJca]
# 3187                         []
# 3188  [https://t.co/Sg5PvZIPFL]
# 3189  [https://t.co/BR4fQGhJZq]
# 3190  [https://t.co/EAUAPKRWEI]
# 3191  [https://t.co/f0sab1ttOL]
# 3192  [https://t.co/1t0XUwXWLv]
# 3193  [https://t.co/aUikoi4JLq]
# 3194  [https://t.co/X4WJtHMliY]
# 3195  [https://t.co/usU5WUEflP]
# 3196  [https://t.co/96yVSlXUsS]
# 3197                         []
# 3198                         []
# 3199                         []
#
#                                              text_clean  \
# 0     I'm done playing by a different set of rules. ...
# 1     Mitch McConnell says efforts to stop gerrymand...
# 2     The Supreme Court's decision is an abomination...
# 3     You bet I have a plan to deal with Mitch McCon...
# 4     The economy is doing great for a thinner and t...
# 5     I spent a big chunk of my life studying why fa...
# 6      : . can make our government, our economy, and...
# 7     I just stepped off the DemDebate stage. I have...
# 8     I’m in this fight for a government and an econ...
# 9     No one should be above the law—that includes t...
# 10    The threat posed by climate change is real, it...
# 11     : Yeah— even has a plan to deal with Mitch Mc...
# 12    We’re fighting for big, structural change to o...
# 13     : Gun violence is a public health emergency i...
# 14    I have a LOT of plans—and you bet I have one t...
# 15    Since running for president, I’ve answered tho...
# 16    As president, I would make sure our country ge...
# 17    I went to the Homestead, FL detention center t...
# 18     : . has a plan to protect our right to safe, ...
# 19     : I agree with : We shouldn't criminalize fam...
# 20     : Our health care system is working great for...
# 21    Every woman should have access to the full ran...
# 22    Women’s rights are human rights. We need to:\n...
# 23     : Health care is a basic human right, and  wi...
# 24     : The economy is doing great for a thinner an...
# 25     : We need courage in Washington to take on co...
# 26    Yes, I would support government-run insurance....
# 27    I’ve spent my life studying why families go br...
# 28    Some politicians say Medicare for All isn’t po...
# 29    As president, I will pursue an agenda of econo...
# ...                                                 ...
# 3170  If you don't think this is how a President Tru...
# 3171  Delighted to have Joanie back on the team.  is...
# 3172  Three generations of celebrating. ImWithHer St...
# 3173  For my daughter, granddaughters, &amp; for all...
# 3174  Glad to join the Dem women of the Senate on st...
# 3175  Texas has been a terrific neighbor to our MA d...
# 3176  Always a great honor to see Governor Dukakis &...
# 3177  If you think I'm a fighter, you should meet my...
# 3178  The best partner a senator could ask for: my f...
# 3179  Don't tell the other states, but hanging out w...
# 3180  Just finished up a terrific interview with  li...
# 3181  Getting ready to speak at the demconvention wi...
# 3182  I'm still fired up &amp; ready to go for , &am...
# 3183  Dem women are going to take back the Senate &a...
# 3184  I love being with the labor council in Philly....
# 3185  ., often referred to as a thin-skinned moneygr...
# 3186  I had a terrific time talking about what's hap...
# 3187  You didn't like a speech explaining why you'll...
# 3188  Thank you DemConvention &amp; thank you Americ...
# 3189  In just a few minutes I’ll take the stage at t...
# 3190  Your speech was terrific, Al! DemConvention De...
# 3191  Bruce &amp; I are hanging out backstage with  ...
# 3192  I've got the best seat in the house: watching ...
# 3193  Tonight I'll be delivering the demconvention k...
# 3194  Getting ready for my big demconvention speech ...
# 3195  Made it to Philly for DNCinPHL! 1st stop strai...
# 3196  Today I told NCLR16 that we’ll never build Tru...
# 3197  .? He cheered on the 2008 housing crisis so he...
# 3198  . started his career helping families fight ho...
# 3199  During the 2008 crash, Latino families were 71...
#
#                                      mentions  \
# 0                                          []
# 1                                          []
# 2                                          []
# 3                                          []
# 4                                          []
# 5                                          []
# 6                       [TeamWarren, ewarren]
# 7                                          []
# 8                                          []
# 9                                          []
# 10                                         []
# 11                      [TeamWarren, ewarren]
# 12                                         []
# 13                               [TeamWarren]
# 14                                         []
# 15                                         []
# 16                                         []
# 17                                         []
# 18                      [TeamWarren, ewarren]
# 19                    [ewarren, JulianCastro]
# 20                               [TeamWarren]
# 21                                         []
# 22                                         []
# 23                      [TeamWarren, ewarren]
# 24                      [TeamWarren, ewarren]
# 25                      [TeamWarren, ewarren]
# 26                                         []
# 27                                         []
# 28                                         []
# 29                                         []
# ...                                       ...
# 3170                                       []
# 3171                        [realDonaldTrump]
# 3172                                       []
# 3173                         [hillaryclinton]
# 3174                         [HillaryClinton]
# 3175                                       []
# 3176                                       []
# 3177                           [maura_healey]
# 3178                               [EdMarkey]
# 3179                                       []
# 3180                            [katiecouric]
# 3181                                       []
# 3182  [BarackObama, HillaryClinton, TimKaine]
# 3183            [realDonaldTrump, emilyslist]
# 3184                                       []
# 3185                        [realDonaldTrump]
# 3186                                       []
# 3187                        [realDonaldTrump]
# 3188                                       []
# 3189                                       []
# 3190                                       []
# 3191                             [joekennedy]
# 3192                                       []
# 3193                                       []
# 3194                                       []
# 3195                                       []
# 3196               [HillaryClinton, timkaine]
# 3197                        [realDonaldTrump]
# 3198                               [timkaine]
# 3199                                       []
#
#                                                hashtags  retweet
# 0                                                    []        0
# 1                                                    []        0
# 2                                                    []        0
# 3                                           [DemDebate]        0
# 4                                           [DemDebate]        0
# 5                           [MedicareForAll, DemDebate]        0
# 6                                           [DemDebate]        1
# 7                                           [DemDebate]        0
# 8                                           [DemDebate]        0
# 9                                           [DemDebate]        0
# 10                            [GreenNewDeal, DemDebate]        0
# 11                                          [DemDebate]        1
# 12                                          [DemDebate]        0
# 13                                                   []        1
# 14                                          [DemDebate]        0
# 15                                          [DemDebate]        0
# 16                                          [DemDebate]        0
# 17                                          [DemDebate]        0
# 18                                [RoeVWade, DemDebate]        1
# 19                                                   []        1
# 20                                                   []        1
# 21                                [RoeVWade, DemDebate]        0
# 22    [RoeVWade, HydeAmendment, TitleX, MedicareForA...        0
# 23                                 [MedicareForAll, De]        1
# 24                                                   []        1
# 25                                          [DemDebate]        1
# 26                          [MedicareForAll, DemDebate]        0
# 27                          [MedicareForAll, DemDebate]        0
# 28                          [MedicareForAll, DemDebate]        0
# 29                                                   []        0
# ...                                                 ...      ...
# 3170                                      [ImWithMarge]        0
# 3171                                                 []        0
# 3172                      [ImWithHer, StrongerTogether]        0
# 3173                      [ImWithHer, StrongerTogether]        0
# 3174                                     [DemsInPhilly]        0
# 3175                      [DemConvention, DemsInPhilly]        0
# 3176                      [DemConvention, DemsInPhilly]        0
# 3177                      [DemConvention, DemsInPhilly]        0
# 3178                      [DemConvention, DemsInPhilly]        0
# 3179                      [DemConvention, DemsInPhilly]        0
# 3180                      [DemConvention, DemsInPhilly]        0
# 3181                      [demconvention, DemsInPhilly]        0
# 3182                       [yeswecan, strongertogether]        0
# 3183                                     [DemsInPhilly]        0
# 3184                      [DemsInPhilly, DemConvention]        0
# 3185                                        [imwithher]        0
# 3186                                     [DemsInPhilly]        0
# 3187                                  [hatersgonnahate]        0
# 3188                      [DemConvention, demsinphilly]        0
# 3189                      [demconvention, DemsinPhilly]        0
# 3190                      [DemConvention, DemsInPhilly]        0
# 3191                                     [DemsInPhilly]        0
# 3192                      [DemConvention, DemsInPhilly]        0
# 3193                      [demconvention, DemsinPhilly]        0
# 3194                      [demconvention, demsinphilly]        0
# 3195                                         [DNCinPHL]        0
# 3196                                           [NCLR16]        0
# 3197                                                 []        0
# 3198                                                 []        0
# 3199                                                 []        0
#
# [3200 rows x 8 columns]

# %%
nlp = en_core_web_sm.load()

# %%
spacy_tweets = []

for doc in nlp.pipe(tweets.text_clean, n_threads = -1):
    spacy_tweets.append(doc)

# %% [markdown]
# ### Getting the tf-idf values of content words

# %%
useful_entities = [u'NORP', u'FACILITY', u'ORG', u'EVENT', u'DATE', u'TIME']

Healthcare = [u'care','affordable care act', u'medicare', u'obamacare',  u'benefits', u'opioid', u'abortion', u'medicaid', u'single payer', u'medication', u'prescription', u'drugs', u'hospital', u'health', u'care']
Terrorism = [u'al', u'terror', u'sanctions', u'drone', u'oil', u'gulf', u'intelligence', u'ISIS', u'military', u'nuclear']
Economy = [u'china', u'tariff', u'mexico', u'fed', u'sec', u'interest', u'rate', u'immigration', u'debt', u'unemployment', u'growth', u'inflation', u'trade war', u'dollar', u'gdp', u'g20', u'recession', u'stock', u'market']
lgbtq = [u'gay', u'lesbian', u'pride', u'community', u'lgbt', u'same-sex', u'marriage', u'orientation', u'parade', u'stonewall', u'riot', u'civil', u'homosexual', u'queer', u'conversion']

# %%
content_tweets = []
for single_tweet in tqdm(spacy_tweets):
    single_tweet_content = []
    for token in single_tweet: 
        if ((token.ent_type_ in useful_entities)  
            or (token.pos_ in [u'NOUN', u'ADJ', u'VERB']) 
            or (token.lower_ in Healthcare)):
            single_tweet_content.append(token)
    content_tweets.append(single_tweet_content)
# Out:
# 100%|██████████| 295/295 [00:00<00:00, 11203.45it/s]

# %%
content_tweets
# Out:
# [[Tying,
#   president,
#   hands,
#   midst,
#   crisis,
#   is,
#   misguided,
#   dangerous,
#   NDAA,
#   amendment,
#   is,
#   authorization,
#   use,
#   military,
#   force,
#   affirms,
#   constitutional,
#   authority,
#   president,
#   keep,
#   military,
#   citizens,
#   allies,
#   safe],
#  [Live,
#   be,
#   speaking,
#   NDAA,
#   amendment,
#   reaffirm,
#   constitutional,
#   authorities,
#   president,
#   must,
#   have,
#   protect,
#   defend,
#   country,
#   Watch],
#  [are,
#   many,
#   aspects,
#   healthcare,
#   system,
#   could,
#   use,
#   dose,
#   transparency,
#   Finding,
#   ways,
#   reform,
#   surprise,
#   billing,
#   patients,
#   are,
#   situation,
#   receive,
#   outsized,
#   bill,
#   emergency,
#   services,
#   is,
#   top,
#   priority,
#   work],
#  [Fostering,
#   sustainable,
#   forest,
#   land,
#   management,
#   policies,
#   impact,
#   wildfires,
#   finding,
#   ways,
#   reduce,
#   fuel,
#   load,
#   are,
#   issues,
#   critical,
#   importance,
#   Discussed,
#   items,
#   more,
#   today,
#   friend],
#  [Raising,
#   smoking,
#   age,
#   to,
#   21,
#   will,
#   help,
#   keep,
#   harmful,
#   tobacco,
#   products,
#   children,
#   hands,
#   Pleased,
#   see,
#   bipartisan,
#   Tobacco21,
#   legislation,
#   pass,
#   today,
#   look,
#   continuing,
#   work,
#   colleagues,
#   ways,
#   protect,
#   kids,
#   addiction],
#  [Senate,
#   border,
#   supplemental,
#   bill,
#   provides,
#   needed,
#   resources,
#   need,
#   long,
#   term,
#   fix,
#   discourages,
#   illegal,
#   immigration,
#   securing,
#   border,
#   closing,
#   legal,
#   loopholes,
#   instituting,
#   mandatory,
#   amp,
#   permanent,
#   E,
#   -,
#   Verify],
#  [Each,
#   year,
#   Education,
#   selects,
#   class,
#   Presidential,
#   graduating,
#   seniors,
#   recognized,
#   success,
#   academics,
#   arts,
#   career,
#   &,
#   amp,
#   technical,
#   education,
#   Congratulations,
#   Alex,
#   being,
#   selected],
#  [encourage, anyone, information, disappearance, call],
#  [Enjoyed,
#   spending,
#   time,
#   the,
#   weekend,
#   raising,
#   awareness,
#   breast,
#   cancer,
#   research,
#   being,
#   Tough,
#   Wear],
#  [Thanks,
#   Utahns,
#   came,
#   town,
#   hall,
#   Appreciated,
#   questions,
#   learning,
#   can,
#   serve,
#   Senate],
#  [statement, regarding, attack, drone],
#  [cost,
#   prescription,
#   drugs,
#   is,
#   area,
#   has,
#   opportunity,
#   help,
#   American,
#   consumers,
#   urge,
#   colleagues,
#   support,
#   the,
#   Prescription,
#   Drug,
#   Rebate,
#   Reform,
#   Act,
#   bill,
#   bring,
#   transparency,
#   drug,
#   pricing,
#   amp,
#   reduce,
#   pocket,
#   costs],
#  [is,
#   pillar,
#   community,
#   example,
#   others,
#   serve,
#   grace,
#   commitment,
#   personal,
#   strength,
#   Proud,
#   present,
#   the,
#   Congressional,
#   Award,
#   Foundation,
#   ’s,
#   recognition,
#   work,
#   improving,
#   lives,
#   Utahns],
#  [is, making, move, attach, -, Verify, bill, defense, bill],
#  [Looking,
#   hearing,
#   Utahns,
#   town,
#   hall,
#   tomorrow,
#   night,
#   Join,
#   the,
#   Provo,
#   City,
#   Hall,
#   Chambers,
#   6:00,
#   p.m.,
#   doors,
#   will,
#   open,
#   5:30,
#   p.m.,
#   utpol],
#  [Strong,
#   leadership,
#   is,
#   needed,
#   the,
#   United,
#   Nations,
#   helping,
#   confront,
#   global,
#   challenges,
#   ’ve,
#   known,
#   many,
#   years,
#   look,
#   supporting,
#   confirmation],
#  [’ve,
#   teamed,
#   address,
#   priorities,
#   NDAA,
#   amendments,
#   improve,
#   access,
#   Utah,
#   ’s,
#   plays,
#   critical,
#   role,
#   national,
#   security,
#   returns,
#   decision,
#   making,
#   management,
#   power,
#   public,
#   lands],
#  [The,
#   Navajo,
#   Utah,
#   Water,
#   Rights,
#   Settlement,
#   Act,
#   2019,
#   is,
#   bipartisan,
#   legislation,
#   would,
#   bring,
#   needed,
#   water,
#   infrastructure,
#   Navajo,
#   Nation,
#   passed,
#   ’ve,
#   included,
#   NDAA,
#   amendment,
#   help,
#   secure,
#   final,
#   passage],
#  [Last,
#   month,
#   record,
#   number,
#   illegal,
#   immigrants,
#   were,
#   apprehended,
#   southern,
#   border,
#   Congress,
#   needs,
#   act,
#   address,
#   crisis,
#   ’ve,
#   introduced,
#   NDAA,
#   amendment,
#   make,
#   program,
#   permanent],
#  [critical,
#   threats,
#   nation,
#   faces,
#   is,
#   NDAA,
#   amendments,
#   aim,
#   address,
#   cybersecurity,
#   threats,
#   weapons,
#   systems,
#   intellectual,
#   property,
#   theft,
#   Chinese,
#   companies,
#   amp,
#   require,
#   partnerships,
#   allies,
#   confront,
#   growing,
#   Chinese,
#   aggression],
#  [2020,
#   provides,
#   national,
#   defense,
#   amp,
#   gives,
#   critical,
#   policy,
#   guidance,
#   Pentagon,
#   have,
#   introduced,
#   amendments,
#   year,
#   defense,
#   bill,
#   require,
#   develop,
#   strategy,
#   address,
#   rise,
#   ones,
#   will,
#   benefit,
#   home,
#   state],
#  [Looking, 's, sure, be, great, season],
#  [Congratulations, great, milestone],
#  [applaud,
#   Administration,
#   ’s,
#   action,
#   will,
#   provide,
#   American,
#   workers,
#   more,
#   choice,
#   comes,
#   health,
#   care,
#   coverage,
#   help,
#   lower,
#   costs],
#  [banning,
#   use,
#   electronic,
#   cigarettes,
#   schools,
#   are,
#   taking,
#   important,
#   step,
#   protect,
#   health,
#   young,
#   people],
#  [thoughts,
#   climate,
#   change,
#   need,
#   encourage,
#   investment,
#   breakthrough,
#   technology,
#   help,
#   tackle,
#   global,
#   problem],
#  [Happy,
#   Birthday,
#   grateful,
#   brave,
#   men,
#   women,
#   serve,
#   defending,
#   country,
#   upholding,
#   freedoms],
#  [Today,
#   attacks,
#   oil,
#   tankers,
#   are,
#   threat,
#   global,
#   peace,
#   security,
#   are,
#   further,
#   evidence,
#   refuses,
#   act,
#   normal,
#   nation,
#   should,
#   continue,
#   stand,
#   partners,
#   amp,
#   allies,
#   safeguard,
#   stability,
#   region],
#  [high,
#   schoolers,
#   are,
#   getting,
#   diplomas—,
#   millions,
#   are,
#   graduating,
#   life,
#   nicotine,
#   add],
#  [extradition,
#   law,
#   proposed,
#   loyalists,
#   would,
#   allow,
#   political,
#   dissidents,
#   minorities,
#   be,
#   spirited,
#   secret,
#   police,
#   join,
#   colleagues,
#   calling,
#   Chinese,
#   authorities,
#   respect,
#   demonstrators,
#   right,
#   protest],
#  [Got,
#   meet,
#   great,
#   group,
#   students,
#   are,
#   talk,
#   National,
#   History,
#   Day,
#   Thanks,
#   stopping,
#   letting,
#   share,
#   stories,
#   known],
#  [Today,
#   introduced,
#   legislation,
#   make,
#   program,
#   permanent,
#   Congress,
#   should,
#   continue,
#   work,
#   find,
#   long,
#   term,
#   fixes,
#   secure,
#   border,
#   update,
#   asylum,
#   trafficking,
#   laws,
#   institute,
#   mandatory,
#   nationwide],
#  [Last,
#   month,
#   13-year,
#   record,
#   illegal,
#   immigrants,
#   were,
#   apprehended,
#   southern,
#   borders,
#   Congress,
#   needs,
#   act,
#   address,
#   illegal,
#   immigration,
#   crisis,
#   closing,
#   legal,
#   loopholes,
#   removing,
#   magnets,
#   illegal,
#   employment,
#   drive,
#   illegal,
#   immigration],
#  [Thank,
#   taking,
#   time,
#   meet,
#   Utah,
#   Advocates,
#   discuss,
#   can,
#   work,
#   save,
#   Lives,
#   …],
#  [loss,
#   life,
#   suicide,
#   is,
#   many,
#   state,
#   lose,
#   average,
#   Utahn,
#   suicide,
#   every,
#   13,
#   hours,
#   Appreciated,
#   sharing,
#   work,
#   reduce,
#   statistics,
#   need,
#   help,
#   someone,
#   know,
#   is,
#   struggling,
#   call],
#  [Finding,
#   treatments,
#   cures,
#   neurologic,
#   diseases,
#   such,
#   MS,
#   ALS,
#   is,
#   passion,
#   mine,
#   Honored,
#   hear,
#   stories,
#   representatives,
#   learn,
#   Congress,
#   can,
#   support,
#   ourALScommunity],
#  [deserved, honor],
#  [said,
#   time,
#   time,
#   man,
#   has,
#   greater,
#   love,
#   neighbor,
#   lay,
#   life,
#   the,
#   Allied,
#   Forces,
#   did,
#   beaches,
#   75,
#   years,
#   ago,
#   today],
#  [message, Today, celebrate, 75th, anniversary, DDay, most, import, …],
#  [Today,
#   75th,
#   Anniversary,
#   honor,
#   the,
#   Greatest,
#   Generation,
#   gave,
#   beaches,
#   could,
#   liberate,
#   entire,
#   continent,
#   will,
#   forget,
#   sacrifices,
#   made,
#   the,
#   Allied,
#   Forces,
#   that,
#   day],
#  [This,
#   week,
#   marks,
#   100th,
#   anniversary,
#   proposed,
#   19th,
#   passing,
#   Senate,
#   did,
#   know,
#   led,
#   charge,
#   granting,
#   women,
#   right,
#   vote,
#   nearly,
#   50,
#   years,
#   earlier,
#   Let,
#   remember,
#   leaders,
#   women,
#   suffrage,
#   movement,
#   efforts],
#  [Today,
#   marks,
#   anniversary,
#   has,
#   pursued,
#   relentless,
#   course,
#   imprisoning,
#   millions,
#   repressing,
#   dissent,
#   censoring,
#   media,
#   internet,
#   must,
#   act,
#   strengthen,
#   stop,
#   predation],
#  [is,
#   great,
#   privilege,
#   represent,
#   people,
#   Today,
#   serving,
#   six,
#   months,
#   am,
#   delivering,
#   maiden,
#   speech,
#   Senate],
#  [Live,
#   be,
#   Senate,
#   delivering,
#   first,
#   speech,
#   will,
#   be,
#   livestreamed,
#   can,
#   be,
#   viewed,
#   Hope,
#   tune],
#  [warns,
#   harmful,
#   consequence,
#   American,
#   consumers,
#   Trump,
#   imposes,
#   tariffs,
#   imports],
#  [Looking,
#   hearing,
#   Utahns,
#   town,
#   hall,
#   tomorrow,
#   night,
#   Join,
#   6:00,
#   p.m.,
#   the,
#   Heber,
#   City,
#   Police,
#   Department,
#   Doors,
#   will,
#   open,
#   5:30,
#   p.m.],
#  [be,
#   lookout,
#   notify,
#   authorities,
#   come,
#   information,
#   Praying,
#   safe,
#   return,
#   family],
#  [must,
#   forget,
#   freedom,
#   comes,
#   dear,
#   cost,
#   Today,
#   honor,
#   men,
#   women,
#   've,
#   lost,
#   service,
#   country,
#   vow,
#   forget,
#   sacrifice],
#  [MilitaryAppreciationMonth,
#   honor,
#   have,
#   fought,
#   are,
#   fighting,
#   keep,
#   safe,
#   free,
#   are,
#   indebted,
#   armed,
#   forces,
#   🇺,
#   🇸],
#  [Welcomed,
#   group,
#   Utahns,
#   discuss,
#   issues,
#   are,
#   impacting,
#   rural,
#   enjoyed,
#   seeing,
#   friends],
#  [owe, great, deal, gratitude, are, fighting, forces, keep, safe, free, appr],
#  [American, people, deserve, Congress, plans, spends, taxpayer, dollars],
#  [rushing,
#   dollar,
#   spending,
#   bills,
#   the,
#   eleventh,
#   hour,
#   sufficient,
#   debate,
#   Congress,
#   must,
#   start,
#   budgeting,
#   natural,
#   disasters,
#   introduced,
#   bill,
#   this,
#   week,
#   would,
#   require,
#   disaster,
#   spending,
#   be,
#   built,
#   annual,
#   budget,
#   process],
#  [promised,
#   people,
#   would,
#   be,
#   rubber,
#   stamp,
#   wasteful,
#   spending,
#   bills,
#   drive,
#   sky,
#   rocketing,
#   national,
#   debt,
#   good,
#   conscience,
#   support],
#  [’s,
#   unfortunate,
#   today,
#   spending,
#   bill,
#   was,
#   aimed,
#   aiding,
#   Americans,
#   affected,
#   natural,
#   disasters,
#   has,
#   been,
#   loaded,
#   billions,
#   dollars,
#   unrelated,
#   pet,
#   projects,
#   growing,
#   just,
#   the,
#   past,
#   few,
#   weeks],
#  [Congratulations,
#   friend,
#   being,
#   nominated,
#   serve,
#   next,
#   plays,
#   critical,
#   role,
#   national,
#   security,
#   look,
#   meeting,
#   discuss,
#   vision,
#   the,
#   Air,
#   Force],
#  [were,
#   honored,
#   help,
#   confirm,
#   native,
#   the,
#   United,
#   States,
#   Court,
#   believe,
#   is,
#   qualified,
#   nominee,
#   will,
#   serve,
#   court,
#   honor,
#   integrity],
#  [Tourism,
#   is,
#   large,
#   part,
#   economy,
#   ski,
#   season,
#   fact,
#   estimates,
#   household,
#   saves,
#   tax,
#   dollars,
#   tourism,
#   spending,
#   ’m,
#   joining,
#   effort,
#   renew,
#   funding],
#  [Opioid,
#   addiction,
#   is,
#   real,
#   problem,
#   country,
#   Appreciate,
#   stopping,
#   office,
#   discuss,
#   ways,
#   can,
#   destigmatize,
#   addiction,
#   share,
#   story,
#   doing,
#   great,
#   work,
#   educate,
#   youth,
#   state,
#   dangers,
#   addiction],
#  [’s,
#   overdue,
#   Congress,
#   start,
#   planning,
#   natural,
#   disasters,
#   's,
#   'm,
#   introducing,
#   bill,
#   would,
#   require,
#   future,
#   disaster,
#   funding,
#   fall,
#   statutory,
#   budget,
#   limits→],
#  [Read, joint, statement, new, Tobacco21, legislation],
#  [hiring,
#   head,
#   coach,
#   last,
#   month,
#   Wolverines,
#   are,
#   going,
#   be,
#   tough,
#   beat,
#   Looking,
#   basketball,
#   season,
#   GoUVU],
#  [is,
#   based,
#   robotics,
#   company,
#   other,
#   things,
#   is,
#   working,
#   develop,
#   robots,
#   could,
#   assist,
#   soldiers,
#   battlefield,
#   Enjoyed,
#   visiting,
#   office,
#   discuss,
#   work,
#   finding,
#   innovative,
#   solutions,
#   future,
#   challenges,
#   country,
#   may,
#   face],
#  [Welcome, home, 109th, Air, Control, Squadron, 🇸],
#  [country,
#   children,
#   deserve,
#   better,
#   can,
#   learn,
#   example,
#   passing,
#   Tobacco,
#   …],
#  [only,
#   place,
#   want,
#   see,
#   tariffs,
#   is,
#   needs,
#   stop,
#   cheating,
#   agreements,
#   international,
#   rules,
#   commerce,
#   trade,
#   open,
#   fair,
#   basis],
#  [years,
#   has,
#   been,
#   cheating,
#   international,
#   rules,
#   commerce,
#   they’re,
#   stealing,
#   technology,
#   intellectual,
#   property,
#   Placing,
#   tariffs,
#   Chinese,
#   goods,
#   is,
#   necessary,
#   step,
#   prevent,
#   continuing,
#   kill,
#   jobs,
#   kill,
#   businesses],
#  [do,
#   believe,
#   Administration,
#   has,
#   interest,
#   going,
#   war,
#   sit,
#   watch,
#   things,
#   unfold,
#   must,
#   make,
#   understand,
#   take,
#   action,
#   people,
#   allies,
#   will,
#   be,
#   consequences],
#  [supports,
#   Trump,
#   tariffs,
#   acknowledges,
#   Americans,
#   pay,
#   cost,
#   says,
#   's,
#   sacrifi,
#   …],
#  [Today, w/],
#  [Tomorrow, w/],
#  [proud,
#   alum,
#   ’ve,
#   said,
#   is,
#   best,
#   school,
#   country,
#   do,
#   have,
#   take,
#   word,
#   has,
#   ranked,
#   Brigham,
#   Young,
#   University,
#   best,
#   value,
#   college,
#   2019],
#  [Met,
#   large,
#   group,
#   Utah,
#   Association,
#   of,
#   Realtors,
#   members,
#   were,
#   this,
#   week,
#   Had,
#   good,
#   discussion,
#   affordable,
#   housing,
#   other,
#   challenges,
#   facing,
#   industry],
#  [Welcomed,
#   representatives,
#   local,
#   chambers,
#   commerce,
#   Capitol,
#   this,
#   week,
#   is,
#   great,
#   place,
#   do,
#   business,
#   had,
#   good,
#   discussion,
#   economic,
#   growth,
#   communities],
#  [Sunday, joins, LIVE, Hope, join],
#  ['s,
#   legal,
#   immigration,
#   system,
#   needs,
#   reform,
#   've,
#   supported,
#   merit,
#   based,
#   system,
#   is,
#   positive,
#   step,
#   discussion,
#   parties,
#   need,
#   work,
#   solution,
#   address,
#   legal,
#   illegal,
#   immigration,
#   strengthen,
#   border,
#   security],
#  [was,
#   impressed,
#   leadership,
#   ground,
#   shared,
#   optimism,
#   additional,
#   leadership,
#   would,
#   come,
#   confirmation,
#   own,
#   confirmation,
#   tonight],
#  [Honored,
#   have,
#   met,
#   families,
#   names,
#   are,
#   being,
#   added,
#   this,
#   week,
#   Next,
#   year,
#   will,
#   recognize,
#   lost,
#   January],
#  [NationalPoliceWeek,
#   honor,
#   law,
#   enforcement,
#   officers,
#   families,
#   make,
#   enormous,
#   sacrifices,
#   country,
#   This,
#   week,
#   honor,
#   lives,
#   lost,
#   2018],
#  [2021,
#   %,
#   nuclear,
#   fleet,
#   will,
#   be,
#   modernized,
#   triad,
#   has,
#   been,
#   modernized,
#   the,
#   1980s,
#   Congress,
#   must,
#   make,
#   modernization,
#   nuclear,
#   deterrent,
#   high,
#   priority,
#   —,
#   includes,
#   standing,
#   Ground,
#   Based,
#   Strategic,
#   Defense,
#   Program],
#  [More,
#   %,
#   Navajo,
#   Nation,
#   households,
#   lack,
#   running,
#   water,
#   bill,
#   will,
#   bring,
#   needed,
#   water,
#   infrastructure,
#   families,
#   Pleased,
#   see,
#   pass,
#   appreciate,
#   efforts,
#   Utah,
#   &,
#   amp,
#   Nation,
#   leadership,
#   making,
#   happen],
#  [Live,
#   be,
#   introducing,
#   the,
#   Navajo,
#   Utah,
#   Water,
#   Rights,
#   Settlement,
#   Act,
#   2019,
#   front,
#   will,
#   bring,
#   needed,
#   water,
#   infrastructure],
#  [decades,
#   has,
#   worked,
#   use,
#   business,
#   success,
#   inspire,
#   improve,
#   lives,
#   Utahns,
#   'm,
#   lucky,
#   call,
#   friend,
#   Congratulations,
#   honor,
#   deserved],
#  [know,
#   tobacco,
#   damages,
#   human,
#   body,
#   tobacco,
#   kills,
#   people,
#   know,
#   number,
#   young,
#   people,
#   vape,
#   has,
#   doubled,
#   Proud,
#   join,
#   colleagues,
#   introducing,
#   important,
#   Tobacco21,
#   legislation],
#  [Promontory, Summit, celebrating, 150th, Anniversary, driving, utpol],
#  [shares, perspective, Spike150],
#  [GoldenSpike,
#   was,
#   inches,
#   weighed,
#   oz,
#   was,
#   made,
#   carat,
#   gold,
#   was,
#   driven,
#   tie,
#   made,
#   polished,
#   laurel,
#   spike,
#   tie,
#   were,
#   removed,
#   replaced,
#   pine,
#   tie,
#   iron,
#   spikes,
#   prevent,
#   theft,
#   Spike150],
#  [must,
#   work,
#   bringing,
#   transparency,
#   healthcare,
#   system,
#   look,
#   working,
#   Administration,
#   colleagues,
#   solutions,
#   ensure,
#   patients,
#   are,
#   empowered,
#   make,
#   informed,
#   decisions,
#   regarding,
#   care],
#  [The,
#   Transcontinental,
#   Railroad,
#   was,
#   extraordinary,
#   engineering,
#   feats,
#   the,
#   19th,
#   century,
#   Tomorrow,
#   celebrate,
#   150th,
#   anniversary,
#   driving,
#   marking,
#   completion,
#   railroad,
#   did,
#   wonders,
#   move,
#   country,
#   Spike150],
#  [patients,
#   face,
#   skyrocketing,
#   prescription,
#   drug,
#   costs,
#   insurance,
#   companies,
#   amp,
#   drug,
#   manufacturers,
#   benefit,
#   complex,
#   system,
#   rebates,
#   'm,
#   introducing,
#   bill,
#   aims,
#   bring,
#   transparency,
#   prescription,
#   drug,
#   pricing,
#   system,
#   amp,
#   lower,
#   pocket,
#   costs,
#   medication],
#  [Looking,
#   hearing,
#   Utahns,
#   town,
#   hall,
#   tomorrow,
#   night,
#   Join,
#   6:30,
#   p.m.,
#   MTECH,
#   Main,
#   Campus,
#   Doors,
#   will,
#   open,
#   6:00,
#   p.m.],
#  [Last,
#   known,
#   Champagne,
#   photo,
#   is,
#   famous,
#   photo,
#   associated,
#   the,
#   First,
#   Continental,
#   Railroad,
#   ceremony,
#   participants,
#   have,
#   been,
#   identified,
#   photo→],
#  [imposing,
#   sanctions,
#   iron,
#   steel,
#   aluminum,
#   copper,
#   sectors,
#   Administration,
#   is,
#   correct,
#   keep,
#   pressure,
#   Given,
#   regime,
#   egregious,
#   actions,
#   recent,
#   past,
#   must,
#   continue,
#   implementing,
#   maximum,
#   pressure,
#   campaign],
#  [Live→,
#   Proud,
#   join,
#   colleagues,
#   important,
#   Tobacco21,
#   legislation,
#   raising,
#   federal,
#   minimum,
#   age,
#   buy,
#   tobacco,
#   products,
#   can,
#   help,
#   keep,
#   harmful,
#   products,
#   children,
#   hands],
#  [Happy, birthday, utpol],
#  [Welcome, home, 🇺, 🇸],
#  [ceremony,
#   was,
#   scheduled,
#   May,
#   8,
#   ,,
#   1869,
#   had,
#   be,
#   postponed,
#   two,
#   days,
#   due,
#   inclement,
#   weather,
#   labor,
#   disputes,
#   facing,
#   Union,
#   Pacific,
#   side,
#   rail,
#   line,
#   Spike150],
#  [Surprise, visitor, office, this, morning, Thanks, stopping, Kid],
#  [Today,
#   trivia,
#   Union,
#   Pacific,
#   ’s,
#   Central,
#   Pacific,
#   ’s,
#   steam,
#   locomotives,
#   were,
#   staged,
#   face,
#   face,
#   driving],
#  [completion,
#   the,
#   Transcontinental,
#   Railroad,
#   helped,
#   unite,
#   nation,
#   ’s,
#   testament,
#   enduring,
#   spirit,
#   ingenuity,
#   industry,
#   Spike150],
#  [May,
#   10,
#   marks,
#   the,
#   150th,
#   anniversary,
#   of,
#   the,
#   GoldenSpike,
#   ceremony,
#   commemorating,
#   completion,
#   the,
#   Transcontinental,
#   Railroad,
#   the,
#   Utah,
#   Territory,
#   the,
#   week,
#   be,
#   sharing,
#   Spike150,
#   trivia],
#  [stand,
#   condemning,
#   Hamas,
#   indiscriminate,
#   rocket,
#   attacks,
#   Israeli,
#   civilians,
#   call,
#   Hamas,
#   uphold,
#   current,
#   ceasefire],
#  [future, potential, peace, plan, are, takeaways, recent, trip],
#  [great, see, friend, appreciate, leadership, state, service, Utahns],
#  [The,
#   4th,
#   Fighter,
#   Squadron,
#   deployed,
#   first,
#   F-35As,
#   used,
#   combat,
#   Proud,
#   see,
#   playing,
#   vital,
#   role,
#   ongoing,
#   fight,
#   ISIS],
#  [Horrific,
#   violence,
#   is,
#   being,
#   perpetrated,
#   Maduro,
#   backed,
#   forces,
#   Venezuelan,
#   people,
#   ’s,
#   appalling,
#   continues,
#   prop,
#   despotic,
#   regime],
#  [Raising,
#   federal,
#   smoking,
#   age,
#   to,
#   21,
#   is,
#   important,
#   step,
#   keeping,
#   harmful,
#   tobacco,
#   products,
#   children,
#   hands,
#   was,
#   first,
#   states,
#   enact,
#   law,
#   'm,
#   proud,
#   join,
#   colleagues,
#   introducing,
#   federal,
#   legislation,
#   follows,
#   lead],
#  [NEWS,
#   nearly,
#   4,
#   months,
#   Senate,
#   basement,
#   Team,
#   Romney,
#   has,
#   moved,
#   new,
#   office,
#   Check],
#  [Welcome, home, 🇸],
#  [Iraq,
#   ’s,
#   Council,
#   of,
#   Representatives,
#   Iraqi,
#   leaders,
#   are,
#   working,
#   good,
#   faith,
#   partners,
#   ours,
#   ensure,
#   peaceful,
#   stable,
#   future,
#   Iraqis,
#   deserve],
#  [men,
#   women,
#   uniform,
#   are,
#   nation,
#   best,
#   brightest,
#   met,
#   Marines,
#   protect,
#   thank,
#   service,
#   🇸],
#  [traveled, meet, discuss, security, economy, future, region],
#  [landing,
#   met,
#   leadership,
#   discuss,
#   security,
#   economic,
#   situation,
#   country,
#   met,
#   staff,
#   thank,
#   work,
#   do],
#  [meetings,
#   took,
#   time,
#   explore,
#   enjoyed,
#   visiting,
#   the,
#   Church,
#   of,
#   the,
#   Holy,
#   Sepulchre],
#  [has,
#   fantastic,
#   campus,
#   offering,
#   students,
#   immersive,
#   courses,
#   biblical,
#   studies,
#   history,
#   Enjoyed,
#   meeting,
#   current,
#   students,
#   the,
#   BYU,
#   Jerusalem,
#   Center,
#   taking,
#   views],
#  [met,
#   officials,
#   discuss,
#   security,
#   concerns,
#   region,
#   is,
#   important,
#   ally,
#   friend,
#   stand,
#   promoting,
#   regional,
#   stability,
#   countering,
#   threat,
#   posed],
#  [faces,
#   complex,
#   challenges,
#   world,
#   the,
#   next,
#   several,
#   days,
#   will,
#   be,
#   meeting,
#   government,
#   officials,
#   working,
#   maintain,
#   strengthen,
#   alliances,
#   key,
#   partners,
#   region],
#  [Congratulations,
#   own,
#   first,
#   first,
#   person,
#   representing,
#   health,
#   care,
#   named,
#   list,
#   Learn,
#   more,
#   work],
#  [celebrate,
#   miracle,
#   Easter,
#   hold,
#   hearts,
#   victims,
#   senseless,
#   violence,
#   loved,
#   ones,
#   pray,
#   may,
#   experience,
#   eternal,
#   grace,
#   comfort,
#   love],
#  [have, read, redacted, report, offer, personal, reaction],
#  [Opportunity,
#   law,
#   following,
#   tax,
#   reform,
#   boost,
#   economic,
#   growth,
#   job,
#   creation,
#   distressed,
#   communities,
#   are,
#   designated,
#   zones,
#   Pleased,
#   see,
#   officials,
#   included,
#   conference],
#  [Proud,
#   partner,
#   the,
#   Navajo,
#   Nation,
#   ,,
#    ,
#   &,
#   amp,
#   resolve,
#   standing,
#   conflict,
#   regarding,
#   water,
#   rights,
#   providing,
#   Navajo,
#   Nation,
#   needed,
#   infrastructure,
#   half,
#   citizens,
#   do,
#   have,
#   running,
#   water],
#  [meets,
#   earlier,
#   today,
#   discusses,
#   regional,
#   developments,
#   bilateral,
#   relations],
#  [Expanding,
#   Association,
#   Health,
#   creates,
#   new,
#   opportunities,
#   Utahns,
#   band,
#   secure,
#   affordable,
#   health,
#   insurance,
#   ’m,
#   proud,
#   join,
#   colleagues,
#   legislation,
#   ensure,
#   small,
#   businesses,
#   individuals,
#   can,
#   access,
#   quality,
#   health,
#   insurance,
#   cheaper,
#   prices],
#  [Based,
#   recent,
#   discussion,
#   years,
#   experience,
#   managing,
#   federal,
#   lands,
#   has,
#   solid,
#   understanding,
#   issues,
#   affecting,
#   Western,
#   states,
#   look,
#   working,
#   ensure,
#   has,
#   voice,
#   public,
#   lands,
#   decisions],
#  [was,
#   conceived,
#   idea,
#   Medicare,
#   proposal,
#   has,
#   price,
#   tag,
#   would,
#   eliminate,
#   competition,
#   health,
#   care,
#   jeopardizing,
#   quality,
#   care,
#   cost,
#   MedicareForAll,
#   is,
#   non,
#   -,
#   starter],
#  [Welcome, home, 1st, was, a, long, 10, months, lived, …],
#  [Congress,
#   must,
#   put,
#   place,
#   processes,
#   measures,
#   make,
#   sure,
#   secure,
#   border,
#   systems,
#   do,
#   attract,
#   people,
#   such,
#   huge,
#   numbers,
#   starters,
#   mandatory,
#   is,
#   essential,
#   turn,
#   magnet,
#   draws,
#   people,
#   country],
#  [am,
#   troubled,
#   vacancies,
#   is,
#   dangerous,
#   given,
#   happening,
#   border,
#   dangerous,
#   given,
#   broad,
#   responsibility,
#   the,
#   Department,
#   of,
#   Homeland,
#   Security,
#   has,
#   protecting,
#   nation],
#  [implementing,
#   drought,
#   contingency,
#   plans,
#   legislation,
#   is,
#   important,
#   step,
#   managing,
#   waters,
#   communities,
#   depend,
#   Pleased,
#   see,
#   bill,
#   headed,
#   desk],
#  [is,
#   doubt,
#   is,
#   state,
#   sponsor,
#   terrorism,
#   support,
#   administration,
#   designation,
#   a,
#   Foreign,
#   Terrorist,
#   Organization,
#   must,
#   continue,
#   maximum,
#   pressure,
#   efforts,
#   hold,
#   regime,
#   accountable,
#   actions],
#  [talks, immigration, health, care, exclusive, interview],
#  [tells,
#   federal,
#   state,
#   partnership,
#   is,
#   wiser,
#   way,
#   go,
#   healthcare,
#   Democrats,
#   agree],
#  [need, complete, border, fence, says, adds, got, deal, asylum, issue],
#  [Live,
#   be,
#   discussing,
#   healthcare,
#   border,
#   security,
#   other,
#   news,
#   the,
#   day,
#   local,
#   affiliate],
#  [Coming, 8, a.m., is, giving, exclusive, interview],
#  [is, tomorrow, morning, 8, a.m.],
#  [TOMORROW, Exclusive, interviews, IfItsSunday],
#  [appreciate,
#   Utahns,
#   came,
#   town,
#   hall,
#   tonight,
#   enjoyed,
#   hearing,
#   everyone,
#   Thank,
#   questions,
#   suggestions,
#   can,
#   serve,
#   Senate],
#  [Gold,
#   Star,
#   let,
#   take,
#   moment,
#   honor,
#   the,
#   Gold,
#   Star,
#   Spouses,
#   country,
#   May,
#   recognize,
#   service,
#   sacrifice,
#   strength,
#   exude,
#   families],
#  [Border,
#   security,
#   should,
#   be,
#   partisan,
#   issue,
#   is,
#   real,
#   crisis,
#   southern,
#   border,
#   must,
#   put,
#   partisan,
#   bickering,
#   do,
#   right,
#   thing,
#   national,
#   security],
#  [ICYMI, joined, writing, op, ed, paid, family, leave, legislat],
#  [Looking,
#   hearing,
#   Utahns,
#   town,
#   hall,
#   tomorrow,
#   night,
#   Join,
#   7:00,
#   p.m.,
#   Room,
#   utpol],
#  [Today,
#   marks,
#   70th,
#   anniversary,
#   signing,
#   creating,
#   alliance,
#   NATO,
#   has,
#   been,
#   imperative,
#   keeping,
#   peace,
#   must,
#   make,
#   effort,
#   continue,
#   supporting,
#   allies],
#  [Having,
#   called,
#   biggest,
#   threats,
#   Romney,
#   introduced,
#   legislation,
#   this,
#   week,
#   aimed,
#   protecting,
#   …],
#  [must,
#   develop,
#   comprehensive,
#   strategy,
#   confront,
#   unprecedented,
#   challenge,
#   Chinese,
#   government,
#   poses,
#   national,
#   security,
#   intellectual,
#   property,
#   businesses,
#   bill,
#   starts,
#   put,
#   puts,
#   safeguards,
#   place,
#   confront,
#   critical,
#   threat,
#   poses],
#  [Concerned,
#   DOD,
#   ’s,
#   list,
#   projects,
#   seeing,
#   funding,
#   delayed,
#   following,
#   national,
#   emergency,
#   declaration,
#   includes,
#   important,
#   projects,
#   Utah,
#   ’s,
#   join,
#   urging,
#   administration,
#   protect,
#   funding,
#   projects,
#   critical,
#   national,
#   security],
#  [Strong,
#   speech,
#   joint,
#   session,
#   Congress,
#   was,
#   heartened,
#   see,
#   enthusiastic,
#   bipartisan,
#   support,
#   NATO,
#   colleagues,
#   more,
#   alliances,
#   are,
#   crucial,
#   confronting,
#   rising,
#   adversarial,
#   powers],
#  [has,
#   been,
#   severe,
#   drought,
#   19,
#   years,
#   low,
#   levels,
#   must,
#   develop,
#   drought,
#   contingency,
#   plan,
#   manage,
#   is,
#   critical,
#   survival,
#   livelihood,
#   recreation,
#   bill,
#   is,
#   important,
#   step],
#  [time,
#   start,
#   working,
#   PaidFamilyLeave,
#   solutions,
#   help,
#   parents,
#   critical,
#   first,
#   few,
#   months,
#   children,
#   lives,
#   proposal,
#   gives,
#   parents,
#   flexibility,
#   take,
#   time,
#   work,
#   pay,
#   growing,
#   national,
#   debt,
#   raising,
#   taxes],
#  [Today,
#   pause,
#   remember,
#   large,
#   group,
#   heroes,
#   Vietnam,
#   War,
#   veterans,
#   are,
#   grateful,
#   service,
#   sacrifice,
#   behalf,
#   country,
#   VietnamWarVeteransDay],
#  [’ve,
#   spent,
#   discretionary,
#   spending,
#   limits,
#   natural,
#   disasters,
#   the,
#   last,
#   five,
#   years,
#   plan,
#   gives,
#   Congress,
#   two,
#   years,
#   plan,
#   disasters,
#   annual,
#   budget,
#   process,
#   time,
#   start,
#   planning,
#   running,
#   government,
#   credit,
#   card],
#  [national,
#   debt,
#   Congress,
#   needs,
#   be,
#   better,
#   balancing,
#   checkbook,
#   means,
#   budgeting,
#   disasters,
#   cost,
#   taxpayers,
#   billions,
#   every,
#   year,
#   ’m,
#   filing,
#   amendment,
#   today,
#   would,
#   put,
#   two,
#   year,
#   path,
#   responsible,
#   disaster,
#   funding],
#  [was,
#   son,
#   definition,
#   American,
#   hero,
#   is,
#   more,
#   deserving,
#   the,
#   Presidential,
#   Medal,
#   of,
#   Honor,
#   country,
#   highest,
#   military,
#   honor],
#  [Thank, joining, today, introducing, NewParentsAct],
#  [Today, joined, introducing, NewParentsAct, responsible, …],
#  [Many,
#   parents,
#   rush,
#   work,
#   having,
#   child,
#   afford,
#   miss,
#   a,
#   few,
#   weeks,
#   pay,
#   is,
#   good,
#   families,
#   NewParentsAct,
#   is,
#   PaidFamilyLeave,
#   proposal,
#   does,
#   create,
#   new,
#   entitlement,
#   program,
#   grow,
#   national,
#   debt,
#   raise,
#   taxes],
#  [Live→, amp, are, unveiling, PaidFamilyLeave, proposal, NewParentsAct],
#  [Society,
#   is,
#   strong,
#   institutions,
#   should,
#   resist,
#   effort,
#   treat,
#   the,
#   Supreme,
#   Court,
#   el],
#  [is,
#   good,
#   news,
#   the,
#   Special,
#   Counsel,
#   has,
#   concluded,
#   campaign,
#   colluded,
#   Russian,
#   government,
#   is,
#   time,
#   country,
#   move],
#  [investigation,
#   led,
#   person,
#   such,
#   honor,
#   integrity,
#   has,
#   applied,
#   rule,
#   law,
#   accusations,
#   fears,
#   contrary],
#  [More, role, national, security, visit→],
#  [Hill,
#   Air,
#   Force,
#   Base,
#   is,
#   vital,
#   country,
#   military,
#   readiness,
#   national,
#   security,
#   Enjoyed,
#   visiting,
#   we're,
#   grateful,
#   men,
#   women,
#   serve],
#  [official,
#   will,
#   be,
#   renamed,
#   honor,
#   fitting,
#   honor,
#   great,
#   man,
#   American,
#   hero],
#  [Welcome, home, 2nd, 74-years, plane, was, shot],
#  [74, years, death, WWII, soldier, remains, returned],
#  [Levied,
#   everything,
#   pacemakers,
#   defibrillators,
#   surgical,
#   tools,
#   hurts,
#   patients,
#   stifles,
#   medical,
#   innovation,
#   Proud,
#   join,
#   dozen,
#   colleagues,
#   bipartisan,
#   legislation],
#  [pleased, has, released, Church, volunteers, are, returning, families],
#  [Yesterday,
#   report,
#   revealed,
#   number,
#   foreign,
#   children,
#   adopted,
#   parents,
#   fell,
#   %,
#   2018,
#   14-year,
#   trend,
#   must,
#   continue,
#   pressure,
#   certain,
#   countries,
#   allow,
#   parents,
#   adopt,
#   children,
#   need],
#  [statement, today, emergency, declaration],
#  [Ending,
#   support,
#   would,
#   undermine,
#   allies,
#   security,
#   interests,
#   region,
#   emboldening,
#   hampering,
#   counterterrorism,
#   efforts,
#   worsening,
#   humanitarian,
#   crisis],
#  [provides,
#   limited,
#   support,
#   Saudi,
#   led,
#   coalition,
#   voted,
#   the,
#   Yemen,
#   War,
#   Powers,
#   Resolution,
#   'm,
#   concerned,
#   would,
#   set,
#   precedent,
#   would,
#   impact,
#   security,
#   partnerships,
#   world,
#   rely,
#   similar,
#   support],
#  [Thank],
#  [may, disagree, best, blow, birthday, candles, best, wishes, happy, birthday],
#  [bipartisan,
#   public,
#   lands,
#   package,
#   includes,
#   many,
#   priorities,
#   county,
#   commissioners,
#   have,
#   fought,
#   Proud,
#   see,
#   important,
#   legislation,
#   be,
#   signed,
#   law],
#  [Thanks],
#  [Thanks, strong, start, birthday, cake],
#  [national,
#   debt,
#   is,
#   more,
#   dollars,
#   this,
#   year,
#   are,
#   set,
#   add,
#   government,
#   must,
#   find,
#   ways,
#   pay,
#   debt,
#   starting,
#   elimination,
#   waste,
#   fraud,
#   abuse,
#   government,
#   programs],
#  [invests,
#   factories,
#   buildings,
#   culture,
#   welcome,
#   news,
#   wants,
#   invest,
#   POS,
#   do,
#   be,
#   fooled,
#   are,
#   looking,
#   stranglehold],
#  [The,
#   Senate,
#   Youth,
#   Program,
#   recognizes,
#   nation,
#   top,
#   student,
#   leaders,
#   Emmalyn,
#   are,
#   brightest,
#   look,
#   continued,
#   accomplishments,
#   part,
#   next,
#   generation,
#   leaders],
#  [Welcomed,
#   large,
#   group,
#   farmers,
#   ranchers,
#   this,
#   morning,
#   talk,
#   agriculture,
#   challenges,
#   trade,
#   policies,
#   would,
#   open,
#   markets,
#   agriculture,
#   exports,
#   visas,
#   land,
#   management,
#   policies,
#   Thanks,
#   coming],
#  [Many,
#   have,
#   questioned,
#   continue,
#   have,
#   military,
#   presence,
#   Questioned,
#   nominees,
#   engagement,
#   is,
#   necessary,
#   security,
#   country,
#   allies,
#   world],
#  [Welcomed,
#   commissioners,
#   Uintah,
#   Iron,
#   counties,
#   nation,
#   capital,
#   yesterday,
#   appreciated,
#   hearing,
#   priorities,
#   am,
#   grateful,
#   service,
#   Look,
#   working],
#  [Multiple,
#   sclerosis,
#   hits,
#   home,
#   ’s,
#   been,
#   almost,
#   20,
#   years,
#   was,
#   diagnosed,
#   Thanks,
#   work,
#   advocating,
#   living,
#   MS,
#   country],
#  [country,
#   is,
#   losing,
#   average,
#   veterans,
#   service,
#   members,
#   a,
#   day,
#   suicide,
#   heartbreaking,
#   is,
#   positive,
#   step,
#   providing,
#   nation,
#   ’s,
#   veterans,
#   care,
#   deserve],
#  [Rising,
#   health,
#   care,
#   costs,
#   are,
#   big,
#   concern,
#   families,
#   small,
#   businesses,
#   joined,
#   fellow,
#   first,
#   term,
#   Senators,
#   urge,
#   Senate,
#   take,
#   action,
#   the,
#   Health,
#   Insurance,
#   Tax,
#   prevent,
#   more,
#   cost,
#   hikes],
#  [mayors,
#   Spanish,
#   Nephi,
#   Levan,
#   members,
#   city,
#   councils,
#   this,
#   week,
#   appreciated,
#   hearing,
#   plans,
#   ensure,
#   inexpensive,
#   reliable,
#   power,
#   residents],
#  [Given,
#   has,
#   closed,
#   many,
#   cultural,
#   centers,
#   government,
#   schools,
#   enter,
#   agreements,
#   should,
#   take,
#   hard,
#   look,
#   should,
#   continue,
#   allow,
#   Confucius,
#   Institutes,
#   operate,
#   country],
#  [have,
#   serious,
#   concerns,
#   little,
#   know,
#   Confucius,
#   Institutes,
#   are,
#   part,
#   influence,
#   campaign,
#   Chinese,
#   government,
#   shape,
#   attitudes,
#   young,
#   Americans],
#  [Great,
#   have,
#   visit,
#   office,
#   this,
#   morning,
#   ’m,
#   looking,
#   working,
#   Congress,
#   ways,
#   bring,
#   cost,
#   prescription,
#   drugs],
#  [more,
#   than,
#   25,
#   years,
#   experience,
#   environmental,
#   policy,
#   is,
#   qualified,
#   lead,
#   look,
#   working,
#   ensure,
#   environmental,
#   policies,
#   help,
#   promote,
#   economic,
#   growth,
#   preserving,
#   environment,
#   natural,
#   resources],
#  [should,
#   be,
#   concerned,
#   do,
#   have,
#   comprehensive,
#   strategy,
#   deal,
#   rise,
#   should,
#   be,
#   urgent,
#   priority,
#   Congress,
#   Administration],
#  [Live,
#   first,
#   Senate,
#   Foreign,
#   Relations,
#   Committee,
#   hearing,
#   Congress,
#   focused,
#   assessing,
#   role,
#   world,
#   can,
#   watch],
#  [Pleased, see, bipartisan, public, lands, package, head, desk, become, law],
#  [Tonight,
#   Senate,
#   Democrats,
#   blocked,
#   vote,
#   the,
#   Born,
#   -,
#   Alive,
#   Abortion,
#   Survivors,
#   Protection,
#   Act,
#   ’s,
#   unconscionable,
#   amp,
#   inhumane,
#   country,
#   members,
#   Congress,
#   are,
#   unwilling,
#   take,
#   stand,
#   support,
#   lives,
#   newborns,
#   survive,
#   abortion,
#   attempt],
#  [GOP,
#   is,
#   leading,
#   senators,
#   wanting,
#   ban,
#   Chinese,
#   tech,
#   giant,
#   supplying,
#   key,
#   parts,
#   energy,
#   …],
#  [Thanks,
#   everyone,
#   joined,
#   Castle,
#   Dale,
#   and,
#   Price,
#   enjoy,
#   visiting,
#   beautiful,
#   part,
#   state,
#   hearing,
#   mind],
#  [Beautiful, day, Looking],
#  [Tomorrow,
#   be,
#   hosting,
#   town,
#   halls,
#   counties,
#   hear,
#   local,
#   residents,
#   Join,
#   3:00,
#   PM,
#   the,
#   Carbon,
#   County,
#   Administration,
#   Building,
#   Price,
#   4:30,
#   PM,
#   utpol],
#  [office,
#   discuss,
#   vision,
#   committee,
#   reforms,
#   Hard,
#   believe,
#   been,
#   20,
#   years,
#   joined,
#   organizing,
#   committee,
#   2002,
#   Winter,
#   Olympic,
#   Games],
#  [Happy, Birthday, country, first, 🎉],
#  [Enjoyed,
#   hearing,
#   everyone,
#   came,
#   tonight,
#   town,
#   hall,
#   Thanks,
#   questions,
#   suggestions,
#   can,
#   serve,
#   Senate],
#  [Fueling, tonight, town, hall, thanks],
#  [tour,
#   update,
#   expansion,
#   project,
#   will,
#   boost,
#   travel,
#   commerce,
#   region,
#   Find,
#   more,
#   TheNewSLC],
#  [Spent,
#   the,
#   afternoon,
#   meeting,
#   legislators,
#   parties,
#   House,
#   Senate,
#   reiterated,
#   ’m,
#   ears,
#   are,
#   things,
#   need,
#   be,
#   done,
#   state,
#   things,
#   care,
#   want,
#   know,
#   utpol,
#   utleg],
#  [Looking,
#   hearing,
#   Utahns,
#   second,
#   town,
#   hall,
#   tonight,
#   Join,
#   the,
#   City,
#   Hall,
#   Council,
#   Chambers,
#   6:00,
#   PM,
#   utpol],
#  [Three,
#   years,
#   ago,
#   Abdusalam,
#   emigrated,
#   enrolling,
#   firefighting,
#   program,
#   ’s,
#   Job,
#   Corps,
#   congratulated,
#   being,
#   named,
#   Best,
#   luck,
#   embark,
#   training,
#   become,
#   wildland,
#   firefighter],
#  [Responsible,
#   energy,
#   development,
#   is,
#   important,
#   energy,
#   industry,
#   rural,
#   economies,
#   lease,
#   agreement,
#   will,
#   bring,
#   jobs,
#   generate,
#   revenue,
#   support,
#   local,
#   economy,
#   counties,
#   protecting,
#   national,
#   resources],
#  [reserve,
#   judgment,
#   potential,
#   executive,
#   action,
#   'm,
#   able,
#   evaluate,
#   ’ve,
#   said,
#   do,
#   believe,
#   declaring,
#   national,
#   emergency,
#   is,
#   right,
#   approach,
#   expect,
#   stay,
#   statutory,
#   constitutional,
#   limits],
#  [today,
#   funding,
#   bill,
#   is,
#   perfect,
#   includes,
#   critical,
#   funding,
#   border,
#   security,
#   immigration,
#   enforcement,
#   prevents,
#   harmful,
#   government,
#   shutdown,
#   am,
#   glad,
#   Senate,
#   was,
#   able,
#   conclude,
#   unfinished,
#   business,
#   last,
#   year],
#  [OTD,
#   149,
#   years,
#   ago,
#   became,
#   first,
#   woman,
#   vote,
#   two,
#   days,
#   the,
#   Utah,
#   Territory,
#   passed,
#   suffrage,
#   laws,
#   women,
#   voted,
#   that,
#   day,
#   nearly,
#   four,
#   decades,
#   passage,
#   the,
#   19th,
#   utpol],
#  [Addie,
#   visited,
#   office,
#   advocate,
#   unified,
#   soccer,
#   team,
#   brought,
#   gold,
#   2018,
#   Enjoyed,
#   hearing,
#   experience,
#   learning,
#   more,
#   unified,
#   sports,
#   Thanks,
#   stopping,
#   office],
#  [first,
#   hearing,
#   today,
#   had,
#   opportunity,
#   thank,
#   work,
#   does,
#   help,
#   small,
#   businesses,
#   rural,
#   parts,
#   state,
#   look,
#   working,
#   continue,
#   efforts],
#  [LandsPackage2019,
#   is,
#   culmination,
#   years,
#   collaboration,
#   cooperation,
#   county,
#   commissioners,
#   local,
#   groups,
#   ensuring,
#   provisions,
#   were,
#   driven,
#   dictated,
#   bureaucrats,
#   legislation,
#   is,
#   good],
#  [previous,
#   administration,
#   stalled,
#   removing,
#   tons,
#   uranium,
#   tailings,
#   Colorado,
#   River,
#   Banks,
#   representatives,
#   Moab,
#   City,
#   Councils,
#   pledge,
#   support,
#   continued,
#   funding,
#   the,
#   Moab,
#   UMTRA,
#   Project],
#  [TUNE,
#   10:00,
#   AM,
#   ET,
#   Senate,
#   health,
#   committee,
#   hearing,
#   can,
#   understand,
#   causes,
#   pain,
#   improve],
#  [thanks, helping, advance, public, lands],
#  [fact,
#   149,
#   years,
#   ago,
#   today,
#   male,
#   territorial,
#   legislature,
#   UNANIMOUSLY,
#   voted,
#   women,
#   suffrage,
#   respect],
#  [Senate,
#   voted,
#   include,
#   ’s,
#   amendment,
#   lands,
#   bill,
#   keep,
#   working,
#   prevent,
#   excessive,
#   land,
#   grabs,
#   bureaucrats,
#   ensure,
#   local,
#   involvement,
#   decisions,
#   made,
#   regarding,
#   public,
#   lands],
#  [is,
#   will,
#   be,
#   public,
#   lands,
#   state,
#   such,
#   must,
#   look,
#   more,
#   public,
#   lands,
#   solutions],
#  [Decisions,
#   made,
#   regarding,
#   public,
#   lands,
#   should,
#   be,
#   made,
#   call,
#   rural,
#   home,
#   bipartisan,
#   public,
#   lands,
#   package,
#   includes,
#   driven,
#   bills,
#   were,
#   crafted,
#   balance,
#   needs,
#   Utahns,
#   conservation,
#   cherished,
#   lands],
#  [Welcomed,
#   Navajo,
#   Nation,
#   other,
#   leaders,
#   office,
#   this,
#   week,
#   look,
#   working,
#   issues,
#   affect,
#   communities],
#  [This,
#   week,
#   met,
#   members,
#   Iron,
#   County,
#   Drug,
#   Prevention,
#   coalitions,
#   learn,
#   work,
#   provide,
#   youths,
#   families,
#   tools,
#   needed,
#   make,
#   good,
#   choices,
#   regarding,
#   drugs,
#   other,
#   substances,
#   impressive,
#   group,
#   students],
#  [Had,
#   opportunity,
#   sample,
#   2018,
#   meeting,
#   the,
#    ,
#   Association,
#   discuss,
#   water,
#   issues,
#   state,
#   water,
#   is,
#   fine],
#  [Today,
#   had,
#   privilege,
#   honoring,
#   fallen,
#   soldiers,
#   Senate,
#   floor,
#   give,
#   thanks,
#   service],
#  [recognizes, families, fallen, service, members, today, …],
#  [is,
#   qualified,
#   serve,
#   provide,
#   strong,
#   leadership,
#   respect,
#   defend,
#   rule,
#   law,
#   maintain,
#   ’s,
#   independence,
#   Read,
#   will,
#   be,
#   voting,
#   support,
#   nomination],
#  [Joined,
#   fellow,
#   Utahns,
#   this,
#   afternoon,
#   honor,
#   life,
#   former,
#   mayor,
#   sacrifices,
#   family,
#   Senate,
#   passed,
#   resolution,
#   this,
#   week,
#   rename,
#   name],
#  [people,
#   love,
#   friendships,
#   have,
#   associations,
#   is,
#   real,
#   currency,
#   life,
#   measure,
#   was,
#   wealthy,
#   man,
#   Today,
#   honored,
#   life,
#   great,
#   man,
#   family],
#  [Speaking, Listen],
#  [welcome,
#   efforts,
#   administration,
#   reach,
#   political,
#   solution,
#   eliminate,
#   ISIS,
#   believe,
#   based,
#   conditions,
#   ground,
#   must,
#   maintain,
#   sufficient,
#   presence,
#   places,
#   protect,
#   national,
#   security,
#   interests],
#  [comes,
#   foreign,
#   policy,
#   have,
#   been,
#   encouraged,
#   administration,
#   decisions,
#   support,
#   people,
#   take,
#   hard,
#   line,
#   Iranian,
#   aggression],
#  [The,
#   Trump,
#   Administration,
#   deserves,
#   credit,
#   working,
#   cut,
#   taxes,
#   regulations,
#   have,
#   helped,
#   boost,
#   economy,
#   raise,
#   wages],
#  [highlighted,
#   several,
#   critical,
#   policy,
#   areas,
#   are,
#   opportunities,
#   parties,
#   work,
#   including,
#   lowering,
#   health,
#   care,
#   costs,
#   reforming,
#   trade,
#   policies,
#   protect,
#   American,
#   workers,
#   strengthening,
#   border,
#   security,
#   immigration,
#   enforcement],
#  [president,
#   speech,
#   was,
#   strong,
#   delivered,
#   appealed,
#   patriotism,
#   common,
#   values,
#   Americans],
#  [Humbled,
#   be,
#   joined,
#   Gold,
#   Star,
#   mother,
#   year,
#   son,
#   was,
#   killed,
#   action,
#   2011],
#  [Humbled, join, rest, delegation, honoring, American, hero, Maj],
#  [played, vital, role, World, War, II, deserved, recognition, utpol],
#  ['m, humbled, be, joined, said, guest, mother, fallen, Navy],
#  [recognition,
#   declared,
#   2019,
#   the,
#   Year,
#   of,
#   the,
#   Train,
#   are,
#   crossroads,
#   west,
#   …],
#  [gave,
#   life,
#   service,
#   country,
#   'm,
#   humbled,
#   be,
#   joined,
#   mother,
#   year,
#   Read,
#   service],
#  [Today,
#   is,
#   organizations,
#   amp,
#   people,
#   world,
#   unite,
#   raise,
#   awareness,
#   cancer,
#   amp,
#   work],
#  [exciting, announcements, UVU, Silicon, UVU, will, offer, first, T, …],
#  [has,
#   continued,
#   bad,
#   behavior,
#   deploying,
#   prohibited,
#   weapons,
#   systems,
#   blatant,
#   violation,
#   INF,
#   treaty,
#   wish,
#   way,
#   deterrence,
#   withdrawing,
#   INF,
#   full,
#   support,
#   NATO,
#   allies,
#   is,
#   right,
#   policy],
#  [Thank, members, service, country, Welcome, home, 🇺, 🇸],
#  [Proud,
#   have,
#   seal,
#   displayed,
#   office,
#   courtesy,
#   proud,
#   alum,
#   is,
#   the,
#   Missile,
#   Defense,
#   Agency],
#  [Met,
#   great,
#   advocates,
#   learn,
#   modern,
#   issues,
#   affecting,
#   blind,
#   population,
#   Thanks,
#   continued,
#   work],
#  [believe,
#   must,
#   expand,
#   parental,
#   choice,
#   create,
#   more,
#   opportunities,
#   education,
#   representatives,
#   learn,
#   more,
#   work,
#   ensure,
#   Utah,
#   ’s,
#   children,
#   amp,
#   families,
#   have,
#   early,
#   access,
#   support,
#   needed,
#   thrive,
#   be,
#   self,
#   sufficient],
#  [continue,
#   believe,
#   premature,
#   withdrawal,
#   forces,
#   would,
#   be,
#   grave,
#   mistake,
#   could,
#   pose,
#   serious,
#   risks,
#   national,
#   security,
#   reason,
#   will,
#   be,
#   supporting,
#   amendment],
#  [has,
#   been,
#   skirting,
#   rules,
#   comes,
#   trade,
#   intellectual,
#   property,
#   discuss,
#   ways,
#   keep,
#   long,
#   term,
#   pressure,
#   play,
#   fair],
#  [TUNE,
#   10:00,
#   AM,
#   ET,
#   Senate,
#   health,
#   committee,
#   hearing,
#   health,
#   centers,
#   providers,
#   underserved,
#   communities,
#   Y],
#  [is,
#   incredible,
#   enduring,
#   symbol,
#   country,
#   democracy,
#   great,
#   experience,
#   ascend,
#   top,
#   today,
#   ️],
#  [convenes,
#   today,
#   best,
#   wishes,
#   state,
#   legislators,
#   May,
#   tradition,
#   bipartisanship,
#   continue,
#   remains,
#   managed,
#   states,
#   country,
#   utpol],
#  [Provo, -, Orem, tops, nation, new, report],
#  [has,
#   year,
#   top,
#   performing,
#   cities,
#   job,
#   creation,
#   economic,
#   growth,
#   is,
#   great,
#   place,
#   live,
#   do,
#   business],
#  [renew,
#   commitment,
#   forget,
#   men,
#   women,
#   children,
#   including,
#   Jews,
#   were,
#   murdered,
#   Today,
#   WeRemember],
#  [’m,
#   encouraged,
#   today,
#   agreement,
#   will,
#   put,
#   people,
#   work,
#   make,
#   sure,
#   get,
#   paid,
#   parties,
#   must,
#   work,
#   the,
#   next,
#   three,
#   weeks,
#   final,
#   agreement,
#   funds,
#   border,
#   security,
#   avoids,
#   shutdown],
#  [have,
#   been,
#   clear,
#   end,
#   shutdown,
#   secure,
#   border,
#   voted,
#   today,
#   do,
#   measures,
#   having,
#   failed,
#   time,
#   Republican,
#   Democratic,
#   leaders,
#   come,
#   negotiate,
#   final,
#   deal,
#   funds,
#   border,
#   security,
#   reopens,
#   government],
#  [is, way, get, things, done, said, shutdown, Tuesday, meeting, 's, bei],
#  [shutdown,
#   woes,
#   border,
#   wall,
#   debates,
#   dominated,
#   first,
#   town,
#   hall,
#   meeting,
#   Tuesday,
#   emphasized,
#   ne,
#   …],
#  [spoke,
#   government,
#   shutdown,
#   border,
#   wall,
#   security,
#   town,
#   hall,
#   Tuesday,
#   have],
#  [put,
#   focus,
#   ongoing,
#   government,
#   shutdown,
#   border,
#   security,
#   first,
#   town,
#   hall,
#   gathering],
#  [was, great, meeting, Thank, service, country],
#  [Thank,
#   Utahns,
#   came,
#   first,
#   town,
#   hall,
#   tonight,
#   Hearing,
#   understanding,
#   perspectives,
#   is,
#   crucial,
#   appreciate,
#   taking,
#   time,
#   join,
#   tonight,
#   share,
#   views],
#  [stopped, visited, this, afternoon, took, little, tour, medical, center],
#  [was,
#   honor,
#   meet,
#   World,
#   War,
#   II,
#   veteran,
#   can,
#   read,
#   incredible,
#   navy,
#   service],
#  [nation,
#   veterans,
#   deserve,
#   absolute,
#   best,
#   care,
#   country,
#   can,
#   offer,
#   Visited,
#   the,
#   VA,
#   Medical,
#   Center,
#   today,
#   learn,
#   services,
#   provide,
#   more,
#   veterans,
#   region],
#  [responsibility,
#   is,
#   Utahns,
#   —,
#   represent,
#   interests,
#   values,
#   Senate,
#   look,
#   hearing,
#   residents,
#   first,
#   town,
#   hall,
#   meeting,
#   tonight],
#  [had,
#   message,
#   anger,
#   resentment,
#   hope,
#   opportunity,
#   had,
#   tremendous,
#   capacity,
#   inspire,
#   uplift,
#   MLKday,
#   honor,
#   champion,
#   civil,
#   rights],
#  [has,
#   put,
#   reasonable,
#   good,
#   faith,
#   proposal,
#   will,
#   reopen,
#   government,
#   help,
#   secure,
#   border,
#   look,
#   voting,
#   will,
#   work,
#   encourage,
#   Republican,
#   Democratic,
#   colleagues,
#   do,
#   same],
#  [is,
#   great,
#   place,
#   do,
#   business,
#   encourage,
#   more,
#   businesses,
#   take,
#   advantage,
#   growing,
#   economy,
#   consider,
#   setting,
#   shop,
#   rural,
#   urban],
#  [growing,
#   economy,
#   chose,
#   other,
#   cities,
#   location,
#   launch,
#   outdoor,
#   gear,
#   company,
#   had,
#   opportunity,
#   meet,
#   family,
#   trip],
#  [has, had, growing, labor, force, state, 2010, growing, more, nation, pace],
#  [commissioners, said, made, mission, impress, plight, families, bus],
#  [human,
#   life,
#   is,
#   sacred,
#   today,
#   march,
#   spirit,
#   compassion,
#   mercy,
#   share,
#   commitment,
#   laws,
#   protect,
#   innocent,
#   will,
#   continue,
#   defending,
#   dignity,
#   life],
#  [attack,
#   is,
#   somber,
#   reminder,
#   threat,
#   ISIS,
#   persists,
#   Administration,
#   decision,
#   retreat,
#   is,
#   grave,
#   mistake],
#  [heart,
#   goes,
#   loved,
#   ones,
#   personnel,
#   killed,
#   terrorist,
#   attack,
#   will,
#   forget,
#   service,
#   sacrifice,
#   protect,
#   values,
#   hold,
#   dear],
#  [got, phone, future, president, Best, luck, take, reins, May],
#  [Great, meeting, today, look, working, public, lands, issues, are, critical],
#  [Congratulations, entrance, look, state, rivalry, games],
#  [amp, regarding, amp],
#  [missed, 's, interview],
#  [had, first, constituents, drop, office, today, came, way],
#  [bureaucrats,
#   have,
#   dictated,
#   counties,
#   ranchers,
#   recreators,
#   can,
#   use,
#   lands,
#   ’m,
#   proud,
#   sponsor,
#   legislation,
#   puts,
#   end,
#   excessive,
#   landgrabs,
#   provides,
#   rural,
#   Utahns,
#   voice,
#   land,
#   management],
#  [Great,
#   meeting,
#   colleague,
#   today,
#   discuss,
#   ways,
#   tackle,
#   priorities,
#   starting,
#   the,
#   Emery,
#   County,
#   Public,
#   Land,
#   Management,
#   Act,
#   led,
#   legislation,
#   serves,
#   model,
#   public,
#   land,
#   decisions,
#   should,
#   be,
#   made],
#  [Spoke,
#   new,
#   this,
#   afternoon,
#   has,
#   big,
#   shoes,
#   fill,
#   passing,
#   remain,
#   confident,
#   will,
#   continue,
#   leading,
#   city,
#   economic,
#   growth],
#  [Each,
#   day,
#   men,
#   women,
#   law,
#   enforcement,
#   put,
#   lives,
#   line,
#   protect,
#   ours,
#   were,
#   reminded,
#   tragic,
#   passing,
#   LawEnforcementAppreciationDay,
#   recognize,
#   do,
#   keep,
#   communities,
#   safe],
#  [state,
#   has,
#   helped,
#   keep,
#   national,
#   parks,
#   open,
#   shutdown,
#   applaud,
#   releasing,
#   additional,
#   funds,
#   dedicated,
#   basic,
#   needs,
#   public,
#   safety,
#   parks,
#   Special,
#   thanks,
#   Utah,
#   House,
#   colleagues,
#   efforts,
#   make,
#   happen],
#  [Heartbroken,
#   tragic,
#   passing,
#   last,
#   night,
#   line,
#   duty,
#   loving,
#   husband,
#   new,
#   father,
#   extend,
#   deepest,
#   condolences,
#   family,
#   friends,
#   fellow,
#   officers,
#   bless,
#   men,
#   women,
#   uniform],
#  [took,
#   politics,
#   drain,
#   Elected,
#   leaders,
#   should,
#   elevate,
#   degrade,
#   public,
#   discourse],
#  [Happy, birthday, beautiful, state],
#  [deep, appreciation],
#  [Used,
#   dad,
#   today,
#   swearing,
#   inscribed,
#   message,
#   time,
#   took,
#   oath,
#   office,
#   did,
#   same,
#   today,
#   ’s,
#   honor,
#   serve],
#  [people, Thank, entrusting, responsibility, serving],
#  [Excited, next, chapter, Let, do]]

# %%
vectorizer = Vectorizer(tf_type='linear', apply_idf=True, idf_type='smooth')

# %%
term_matrix = vectorizer.fit_transform([tok.lemma_ for tok in doc] for doc in spacy_tweets)

# %%
np_matrix = term_matrix.todense()

# %%
np_matrix.shape
# Out:
# (295, 2001)

# %%
for key in sorted(vectorizer.vocabulary_terms)[1000:1015]:
    print(key, vectorizer.vocabulary_terms[key])
# Out:
# energy 1000
# enforcement 1001
# engagement 1002
# engineering 1003
# enjoy 1004
# enormous 1005
# enough 1006
# enrol 1007
# ensure 1008
# enter 1009
# enthusiastic 1010
# entire 1011
# entitlement 1012
# entrance 1013
# entrust 1014

# %%
for token in content_tweets[89]:
    print(token.lemma_, vectorizer.vocabulary_terms[token.lemma_], 
          np.max(np_matrix[:,vectorizer.vocabulary_terms[token.lemma_]]))
# Out:
# patient 1483 5.0809215418899605
# face 1050 9.221835825288448
# skyrocket 1713 5.997212273764115
# prescription 1533 10.60813018640834
# drug 965 15.242764625669881
# cost 859 8.584928363051379
# insurance 1243 11.183494331311902
# company 820 5.0809215418899605
# amp 648 7.964618506443701
# drug 965 15.242764625669881
# manufacturer 1340 5.997212273764115
# benefit 716 5.591747165655951
# complex 826 5.591747165655951
# system 1785 9.221835825288448
# rebate 1584 5.997212273764115
# be 705 6.587737349619255
# introduce 1251 4.125410096862524
# bill 725 7.599975392855791
# aim 632 5.0809215418899605
# bring 744 4.387774361330015
# transparency 1854 5.0809215418899605
# prescription 1533 10.60813018640834
# drug 965 15.242764625669881
# pricing 1543 5.591747165655951
# system 1785 9.221835825288448
# amp 648 7.964618506443701
# lower 1326 5.591747165655951
# pocket 1515 5.591747165655951
# cost 859 8.584928363051379
# medication 1353 5.997212273764115

# %%
tfidf_dict = {}
content_vocab = []
for tweet in content_tweets: 
    for token in tweet: 
        if token.lemma_ not in tfidf_dict: 
            content_vocab.append(token.lemma_)
            tfidf_dict[token.lemma_] = np.max(np_matrix[:,vectorizer.vocabulary_terms[token.lemma_]])

# %%
content_vocab
# Out:
# ['tie',
#  'president',
#  'hand',
#  'midst',
#  'crisis',
#  'be',
#  'misguided',
#  'dangerous',
#  'NDAA',
#  'amendment',
#  'authorization',
#  'use',
#  'military',
#  'force',
#  'affirm',
#  'constitutional',
#  'authority',
#  'keep',
#  'citizen',
#  'ally',
#  'safe',
#  'live',
#  'speak',
#  'reaffirm',
#  'must',
#  'have',
#  'protect',
#  'defend',
#  'country',
#  'watch',
#  'many',
#  'aspect',
#  'healthcare',
#  'system',
#  'could',
#  'dose',
#  'transparency',
#  'find',
#  'way',
#  'reform',
#  'surprise',
#  'billing',
#  'patient',
#  'situation',
#  'receive',
#  'outsized',
#  'bill',
#  'emergency',
#  'service',
#  'top',
#  'priority',
#  'work',
#  'foster',
#  'sustainable',
#  'forest',
#  'land',
#  'management',
#  'policy',
#  'impact',
#  'wildfire',
#  'reduce',
#  'fuel',
#  'load',
#  'issue',
#  'critical',
#  'importance',
#  'discuss',
#  'item',
#  'more',
#  'today',
#  'friend',
#  'raise',
#  'smoking',
#  'age',
#  'to',
#  '21',
#  'will',
#  'help',
#  'harmful',
#  'tobacco',
#  'product',
#  'child',
#  'pleased',
#  'see',
#  'bipartisan',
#  'tobacco21',
#  'legislation',
#  'pass',
#  'look',
#  'continue',
#  'colleague',
#  'kid',
#  'addiction',
#  'Senate',
#  'border',
#  'supplemental',
#  'provide',
#  'need',
#  'resource',
#  'long',
#  'term',
#  'fix',
#  'discourage',
#  'illegal',
#  'immigration',
#  'secure',
#  'close',
#  'legal',
#  'loophole',
#  'institute',
#  'mandatory',
#  'amp',
#  'permanent',
#  'E',
#  '-',
#  'Verify',
#  'each',
#  'year',
#  'Education',
#  'select',
#  'class',
#  'Presidential',
#  'graduate',
#  'senior',
#  'recognize',
#  'success',
#  'academic',
#  'art',
#  'career',
#  '&',
#  'technical',
#  'education',
#  'congratulation',
#  'Alex',
#  'encourage',
#  'anyone',
#  'information',
#  'disappearance',
#  'call',
#  'enjoy',
#  'spending',
#  'time',
#  'the',
#  'weekend',
#  'awareness',
#  'breast',
#  'cancer',
#  'research',
#  'tough',
#  'wear',
#  'thank',
#  'Utahns',
#  'come',
#  'town',
#  'hall',
#  'appreciate',
#  'question',
#  'learn',
#  'can',
#  'serve',
#  'statement',
#  'regard',
#  'attack',
#  'drone',
#  'cost',
#  'prescription',
#  'drug',
#  'area',
#  'opportunity',
#  'american',
#  'consumer',
#  'urge',
#  'support',
#  'Prescription',
#  'Drug',
#  'Rebate',
#  'Reform',
#  'Act',
#  'bring',
#  'pricing',
#  'pocket',
#  'pillar',
#  'community',
#  'example',
#  'other',
#  'grace',
#  'commitment',
#  'personal',
#  'strength',
#  'proud',
#  'present',
#  'Congressional',
#  'Award',
#  'Foundation',
#  '’s',
#  'recognition',
#  'improve',
#  'life',
#  'make',
#  'move',
#  'attach',
#  'verify',
#  'defense',
#  'hear',
#  'tomorrow',
#  'night',
#  'join',
#  'Provo',
#  'City',
#  'Hall',
#  'Chambers',
#  '6:00',
#  'p.m.',
#  'door',
#  'open',
#  '5:30',
#  'utpol',
#  'strong',
#  'leadership',
#  'United',
#  'Nations',
#  'confront',
#  'global',
#  'challenge',
#  'know',
#  'confirmation',
#  'team',
#  'address',
#  'access',
#  'Utah',
#  'play',
#  'role',
#  'national',
#  'security',
#  'return',
#  'decision',
#  'making',
#  'power',
#  'public',
#  'Navajo',
#  'Water',
#  'Rights',
#  'Settlement',
#  '2019',
#  'would',
#  'water',
#  'infrastructure',
#  'Nation',
#  'include',
#  'final',
#  'passage',
#  'last',
#  'month',
#  'record',
#  'number',
#  'immigrant',
#  'apprehend',
#  'southern',
#  'Congress',
#  'act',
#  'introduce',
#  'program',
#  'threat',
#  'nation',
#  'face',
#  'aim',
#  'cybersecurity',
#  'weapon',
#  'intellectual',
#  'property',
#  'theft',
#  'chinese',
#  'company',
#  'require',
#  'partnership',
#  'grow',
#  'aggression',
#  '2020',
#  'give',
#  'guidance',
#  'Pentagon',
#  'develop',
#  'strategy',
#  'rise',
#  'one',
#  'benefit',
#  'home',
#  'state',
#  'sure',
#  'great',
#  'season',
#  'milestone',
#  'applaud',
#  'Administration',
#  'action',
#  'worker',
#  'choice',
#  'health',
#  'care',
#  'coverage',
#  'low',
#  'ban',
#  'electronic',
#  'cigarette',
#  'school',
#  'take',
#  'important',
#  'step',
#  'young',
#  'people',
#  'thought',
#  'climate',
#  'change',
#  'investment',
#  'breakthrough',
#  'technology',
#  'tackle',
#  'problem',
#  'happy',
#  'birthday',
#  'grateful',
#  'brave',
#  'man',
#  'woman',
#  'uphold',
#  'freedom',
#  'oil',
#  'tanker',
#  'peace',
#  'further',
#  'evidence',
#  'refuse',
#  'normal',
#  'should',
#  'stand',
#  'partner',
#  'safeguard',
#  'stability',
#  'region',
#  'high',
#  'schooler',
#  'get',
#  'diplomas—',
#  'million',
#  'nicotine',
#  'add',
#  'extradition',
#  'law',
#  'propose',
#  'loyalist',
#  'allow',
#  'political',
#  'dissident',
#  'minority',
#  'spirit',
#  'secret',
#  'police',
#  'respect',
#  'demonstrator',
#  'right',
#  'protest',
#  'got',
#  'meet',
#  'group',
#  'student',
#  'talk',
#  'National',
#  'History',
#  'Day',
#  'stop',
#  'let',
#  'share',
#  'story',
#  'update',
#  'asylum',
#  'traffic',
#  'nationwide',
#  '13-year',
#  'remove',
#  'magnet',
#  'employment',
#  'drive',
#  'Advocates',
#  'save',
#  '…',
#  'loss',
#  'suicide',
#  'lose',
#  'average',
#  'Utahn',
#  'every',
#  '13',
#  'hour',
#  'statistic',
#  'someone',
#  'struggle',
#  'treatment',
#  'cure',
#  'neurologic',
#  'disease',
#  'such',
#  'MS',
#  'ALS',
#  'passion',
#  'mine',
#  'honor',
#  'representative',
#  'ouralscommunity',
#  'deserve',
#  'say',
#  'love',
#  'neighbor',
#  'lay',
#  'Allied',
#  'Forces',
#  'do',
#  'beach',
#  '75',
#  'ago',
#  'message',
#  'celebrate',
#  '75th',
#  'anniversary',
#  'DDay',
#  'most',
#  'import',
#  'Greatest',
#  'Generation',
#  'liberate',
#  'entire',
#  'continent',
#  'forget',
#  'sacrifice',
#  'that',
#  'day',
#  'this',
#  'week',
#  'mark',
#  '100th',
#  '19th',
#  'lead',
#  'charge',
#  'grant',
#  'vote',
#  'nearly',
#  '50',
#  'earlier',
#  'remember',
#  'leader',
#  'suffrage',
#  'movement',
#  'effort',
#  'pursue',
#  'relentless',
#  'course',
#  'imprison',
#  'repress',
#  'dissent',
#  'censor',
#  'medium',
#  'internet',
#  'strengthen',
#  'predation',
#  'privilege',
#  'represent',
#  'six',
#  'deliver',
#  'maiden',
#  'speech',
#  'first',
#  'livestreame',
#  'view',
#  'hope',
#  'tune',
#  'warn',
#  'consequence',
#  'Trump',
#  'impose',
#  'tariff',
#  'Heber',
#  'Police',
#  'Department',
#  'lookout',
#  'notify',
#  'pray',
#  'family',
#  'dear',
#  'vow',
#  'MilitaryAppreciationMonth',
#  'fight',
#  'free',
#  'indebte',
#  'armed',
#  '🇺',
#  '🇸',
#  'welcome',
#  'rural',
#  'owe',
#  'deal',
#  'gratitude',
#  'fighting',
#  'appr',
#  'plan',
#  'spend',
#  'taxpayer',
#  'dollar',
#  'rush',
#  'eleventh',
#  'sufficient',
#  'debate',
#  'start',
#  'budget',
#  'natural',
#  'disaster',
#  'build',
#  'annual',
#  'process',
#  'promise',
#  'rubber',
#  'stamp',
#  'wasteful',
#  'sky',
#  'rocket',
#  'debt',
#  'good',
#  'conscience',
#  '’',
#  'unfortunate',
#  'aid',
#  'Americans',
#  'affect',
#  'billion',
#  'unrelated',
#  'pet',
#  'project',
#  'just',
#  'past',
#  'few',
#  'nominate',
#  'next',
#  'vision',
#  'Air',
#  'Force',
#  'confirm',
#  'native',
#  'States',
#  'Court',
#  'believe',
#  'qualified',
#  'nominee',
#  'court',
#  'integrity',
#  'tourism',
#  'large',
#  'part',
#  'economy',
#  'ski',
#  'fact',
#  'estimate',
#  'household',
#  'tax',
#  'renew',
#  'funding',
#  'Opioid',
#  'real',
#  'office',
#  'destigmatize',
#  'educate',
#  'youth',
#  'danger',
#  'overdue',
#  'future',
#  'fall',
#  'statutory',
#  'limits→',
#  'read',
#  'joint',
#  'new',
#  'hiring',
#  'head',
#  'coach',
#  'wolverine',
#  'go',
#  'beat',
#  'basketball',
#  'GoUVU',
#  'base',
#  'robotic',
#  'thing',
#  'robot',
#  'assist',
#  'soldier',
#  'battlefield',
#  'visit',
#  'innovative',
#  'solution',
#  'may',
#  '109th',
#  'Control',
#  'Squadron',
#  'well',
#  'Tobacco',
#  'only',
#  'place',
#  'want',
#  'cheat',
#  'agreement',
#  'international',
#  'rule',
#  'commerce',
#  'trade',
#  'fair',
#  'basis',
#  'they’re',
#  'stealing',
#  'necessary',
#  'prevent',
#  'kill',
#  'job',
#  'business',
#  'interest',
#  'war',
#  'sit',
#  'unfold',
#  'understand',
#  'acknowledge',
#  'pay',
#  'sacrifi',
#  'w/',
#  'alum',
#  'word',
#  'rank',
#  'Brigham',
#  'Young',
#  'University',
#  'value',
#  'college',
#  'met',
#  'Association',
#  'of',
#  'Realtors',
#  'member',
#  'discussion',
#  'affordable',
#  'housing',
#  'industry',
#  'local',
#  'chamber',
#  'Capitol',
#  'economic',
#  'growth',
#  'Sunday',
#  'merit',
#  'positive',
#  'party',
#  'impress',
#  'ground',
#  'optimism',
#  'additional',
#  'own',
#  'tonight',
#  'name',
#  'January',
#  'NationalPoliceWeek',
#  'enforcement',
#  'officer',
#  'enormous',
#  '2018',
#  '2021',
#  '%',
#  'nuclear',
#  'fleet',
#  'modernize',
#  'triad',
#  '1980',
#  'modernization',
#  'deterrent',
#  '—',
#  'Ground',
#  'Strategic',
#  'Defense',
#  'Program',
#  'More',
#  'lack',
#  'run',
#  'happen',
#  'front',
#  'decade',
#  'inspire',
#  'lucky',
#  'damage',
#  'human',
#  'body',
#  'vape',
#  'double',
#  'Promontory',
#  'Summit',
#  '150th',
#  'driving',
#  'perspective',
#  'spike150',
#  'GoldenSpike',
#  'inch',
#  'weigh',
#  'oz',
#  'carat',
#  'gold',
#  'polished',
#  'laurel',
#  'spike',
#  'replace',
#  'pine',
#  'iron',
#  'ensure',
#  'empower',
#  'informed',
#  'Transcontinental',
#  'Railroad',
#  'extraordinary',
#  'engineering',
#  'feat',
#  'century',
#  'completion',
#  'railroad',
#  'wonder',
#  'skyrocket',
#  'insurance',
#  'manufacturer',
#  'complex',
#  'rebate',
#  'lower',
#  'medication',
#  '6:30',
#  'MTECH',
#  'Main',
#  'Campus',
#  'Champagne',
#  'photo',
#  'famous',
#  'associate',
#  'First',
#  'Continental',
#  'ceremony',
#  'participant',
#  'identify',
#  'photo→',
#  'sanction',
#  'steel',
#  'aluminum',
#  'copper',
#  'sector',
#  'correct',
#  'pressure',
#  'regime',
#  'egregious',
#  'recent',
#  'implement',
#  'maximum',
#  'campaign',
#  'live→',
#  'federal',
#  'minimum',
#  'buy',
#  'schedule',
#  'May',
#  '8',
#  ',',
#  '1869',
#  'postpone',
#  'two',
#  'due',
#  'inclement',
#  'weather',
#  'labor',
#  'dispute',
#  'Union',
#  'Pacific',
#  'side',
#  'rail',
#  'line',
#  'visitor',
#  'morning',
#  'trivia',
#  'Central',
#  'steam',
#  'locomotive',
#  'stage',
#  'unite',
#  'testament',
#  'endure',
#  'ingenuity',
#  '10',
#  'commemorate',
#  'Territory',
#  'condemn',
#  'Hamas',
#  'indiscriminate',
#  'israeli',
#  'civilian',
#  'current',
#  'ceasefire',
#  'potential',
#  'takeaway',
#  'trip',
#  '4th',
#  'Fighter',
#  'deploy',
#  'f-35a',
#  'combat',
#  'vital',
#  'ongoing',
#  'ISIS',
#  'horrific',
#  'violence',
#  'perpetrate',
#  'Maduro',
#  'back',
#  'venezuelan',
#  'appal',
#  'prop',
#  'despotic',
#  'enact',
#  'follow',
#  'news',
#  '4',
#  'basement',
#  'Team',
#  'Romney',
#  'check',
#  'Iraq',
#  'Council',
#  'Representatives',
#  'iraqi',
#  'faith',
#  'our',
#  'peaceful',
#  'stable',
#  'Iraqis',
#  'uniform',
#  'bright',
#  'Marines',
#  'travel',
#  'staff',
#  'meeting',
#  'explore',
#  'Church',
#  'Holy',
#  'Sepulchre',
#  'fantastic',
#  'campus',
#  'offer',
#  'immersive',
#  'biblical',
#  'study',
#  'history',
#  'BYU',
#  'Jerusalem',
#  'Center',
#  'official',
#  'concern',
#  'promote',
#  'regional',
#  'counter',
#  'pose',
#  'world',
#  'several',
#  'government',
#  'maintain',
#  'alliance',
#  'key',
#  'person',
#  'list',
#  'miracle',
#  'Easter',
#  'hold',
#  'heart',
#  'victim',
#  'senseless',
#  'experience',
#  'eternal',
#  'comfort',
#  'redact',
#  'report',
#  'reaction',
#  'boost',
#  'creation',
#  'distressed',
#  'designate',
#  'zone',
#  'conference',
#  ' ',
#  'resolve',
#  'conflict',
#  'half',
#  'running',
#  'development',
#  'bilateral',
#  'relation',
#  'expand',
#  'Health',
#  'create',
#  'band',
#  'small',
#  'individual',
#  'quality',
#  'cheap',
#  'price',
#  'manage',
#  'solid',
#  'understanding',
#  'western',
#  'voice',
#  'conceive',
#  'idea',
#  'Medicare',
#  'proposal',
#  'tag',
#  'eliminate',
#  'competition',
#  'jeopardize',
#  'medicareforall',
#  'non',
#  'starter',
#  '1st',
#  'a',
#  'put',
#  'measure',
#  'attract',
#  'huge',
#  'essential',
#  'turn',
#  'draw',
#  'troubled',
#  'vacancy',
#  'broad',
#  'responsibility',
#  'Homeland',
#  'Security',
#  'drought',
#  'contingency',
#  'depend',
#  'desk',
#  'doubt',
#  'sponsor',
#  'terrorism',
#  'administration',
#  'designation',
#  'Foreign',
#  'Terrorist',
#  'Organization',
#  'accountable',
#  'exclusive',
#  'interview',
#  'tell',
#  'wise',
#  'Democrats',
#  'agree',
#  'complete',
#  'fence',
#  'affiliate',
#  'a.m.',
#  'ifitssunday',
#  'hearing',
#  'everyone',
#  'suggestion',
#  'Gold',
#  'Star',
#  'moment',
#  'Spouses',
#  'exude',
#  'partisan',
#  'bickering',
#  'icymi',
#  'write',
#  'op',
#  'ed',
#  'leave',
#  'legislat',
#  '7:00',
#  'room',
#  '70th',
#  'signing',
#  'NATO',
#  'imperative',
#  'big',
#  'comprehensive',
#  'unprecedented',
#  'concerned',
#  'DOD',
#  'delay',
#  'declaration',
#  'session',
#  'hearten',
#  'enthusiastic',
#  'crucial',
#  'adversarial',
#  'severe',
#  '19',
#  'level',
#  'survival',
#  ...]

# %%
for key in sorted(tfidf_dict)[500:505]:
    print ("WORD:" + str(key) + " -- tf-idf SCORE:" +  str(tfidf_dict[key]))
# Out:
# WORD:crisis -- tf-idf SCORE:4.898599985096006
# WORD:critical -- tf-idf SCORE:4.125410096862524
# WORD:crossroad -- tf-idf SCORE:5.997212273764115
# WORD:crucial -- tf-idf SCORE:5.591747165655951
# WORD:culmination -- tf-idf SCORE:5.997212273764115

# %%
tfidf_dict['economy']
# Out:
# 9.488898610537493

# %%
from pymprog import *
begin('COWTS')
# Out:
# model('COWTS') is the default model.

# %%
x = var('x', len(spacy_tweets), bool)

# Check this worked

# %%
y = var('y', len(content_vocab), bool)
len(y), y[0]
# Out:
# (1500, 0 <= y[0] <= 1 binary)

# %%
maximize(sum(x) + sum([tfidf_dict[content_vocab[j]]*y[j] for j in range(len(y))]));

# %%
## Maximum length of the entire tweet summary

# Was 150 for the tweet summary, 
# But generated a 1000 word summary for CONABS
L = 1000

# hiding the output of this line since its a very long sum 
sum([x[i]*len(spacy_tweets[i]) for i in range(len(x))]) <= L;

# %%
def content_words(i):
    '''Given a tweet index i (for x[i]), this method will return the indices of the words in the 
    content_vocab[] array
    Note: these indices are the same as for the y variable
    '''
    tweet = spacy_tweets[i]
    content_indices = []
    
    for token in tweet:
        if token.lemma_ in content_vocab:
            content_indices.append(content_vocab.index(token.lemma_))
    return content_indices

# %%
def tweets_with_content_words(j):
    '''Given the index j of some content word (for content_vocab[j] or y[j])
    this method will return the indices of all tweets which contain this content word
    '''
    content_word = content_vocab[j]
    
    index_in_term_matrix = vectorizer.vocabulary_terms[content_word]
    
    matrix_column = np_matrix[:, index_in_term_matrix]
    
    return np.nonzero(matrix_column)[0]

# %%
for j in range(len(y)):
    sum([x[i] for i in tweets_with_content_words(j)])>= y[j]

# %%
for i in range(len(x)):
    sum(y[j] for j in content_words(i)) >= len(content_words(i))*x[i]

# %%
solve()
# Out:
# (0,
#  'The MIP problem instance has been successfully solved. (This code\ndoes {\\it not} necessarily mean that the solver has found optimal\nsolution. It only means that the solution process was successful.)')

# %%
result_x =  [value.primal for value in x]
result_y = [value.primal for value in y]

# %%
end()
# Out:
# model('COWTS') is not the default model.

# %%
chosen_tweets = np.nonzero(result_x)
chosen_words = np.nonzero(result_y)

# %%
len(chosen_tweets[0]), len(chosen_words[0])
# Out:
# (31, 466)

# %%
for i in chosen_tweets[0]:
    print('--------------')
    print(spacy_tweets[i])
# Out:
# --------------
# Fostering sustainable forest and land management policies, the impact of wildfires, and finding ways to reduce fuel load are all issues of critical importance to Utah. Discussed these items and more today with my friend .
# --------------
# The Senate border supplemental bill provides much-needed resources for  and . But we urgently need a long-term fix that discourages illegal immigration by securing the border, closing legal loopholes, and instituting mandatory &amp; permanent E-Verify.
# --------------
# My thoughts on climate change and the need to encourage investment in breakthrough technology to help tackle this global problem.
# --------------
#  : Sen. Mitt Romney warns of ’increasingly harmful consequence’ for American consumers if Trump imposes tariffs on imports…
# --------------
# By 2021, 90% of Russia’s nuclear fleet will be modernized. Our triad hasn't been modernized since the 1980s. Congress must make the modernization of our nuclear deterrent a high priority—which includes standing up the Ground Based Strategic Defense Program at Utah's .
# --------------
# While patients face skyrocketing prescription drug costs, insurance companies &amp; drug manufacturers benefit from a complex system of rebates. I'm introducing a bill that aims to bring transparency to the prescription drug pricing system &amp; lower out-of-pocket costs for medication.
# --------------
# Welcome home 🇺🇸
# --------------
# The Golden Spike ceremony was originally scheduled for May 8, 1869, but had to be postponed two days due to inclement weather and labor disputes facing the Union Pacific side of the rail line. Spike150
# --------------
# Surprise visitor to our office this morning. Thanks for stopping by, Twinkie the Kid!
# --------------
# We stand with Israel in condemning Hamas' indiscriminate rocket attacks against Israeli civilians and call on Hamas to uphold the current ceasefire.
# --------------
# The 4th Fighter Squadron out of Utah’s Hill Air Force Base deployed the Air Force’s first F-35As used in combat. Proud to see  playing a vital role in the ongoing fight against ISIS.
# --------------
# Horrific violence is being perpetrated by Maduro-backed forces against the Venezuelan people. It’s appalling that Russia continues to prop up this despotic regime.
# --------------
# . has a fantastic campus in the Holy Land, offering students immersive courses in biblical studies and Near Eastern history. Enjoyed meeting with current students at the BYU Jerusalem Center and taking in the views of the West Bank.
# --------------
# Opportunity Zones, now law following tax reform, boost economic growth and job creation in distressed communities. There are 46 of these designated zones across Utah. Pleased to see Utah officials included in this conference.
# --------------
# We must develop a comprehensive strategy to confront the unprecedented challenge the Chinese government poses to our national security, intellectual property, and businesses. This bill starts to put puts safeguards in place to confront the critical threat China poses.
# --------------
# We’ve spent $41 billion beyond the discretionary spending limits on natural disasters over the last five years. My plan gives Congress two years to plan for disasters in the annual budget process. It’s time we start planning ahead instead of running up the government credit card.
# --------------
# Many parents rush back to work after having a child because they can’t afford to miss a few weeks of pay. This isn’t good for families. Our NewParentsAct is a PaidFamilyLeave proposal that doesn’t create a new entitlement program, grow our national debt, or raise taxes.
# --------------
#  : 74 years after death, WWII soldier's remains returned to Utah
# --------------
# Levied on everything from pacemakers to defibrillators and surgical tools, the Medical Device Tax hurts patients and stifles medical innovation. Proud to join nearly two dozen colleagues on bipartisan legislation to RepealDeviceTax.
# --------------
# Ending this support would undermine our allies and our security interests in the region by emboldening Iran, hampering counterterrorism efforts, and potentially worsening the humanitarian crisis.
# --------------
# Tonight, Senate Democrats blocked a vote on the Born-Alive Abortion Survivors Protection Act. It’s unconscionable &amp; inhumane that some in our country, especially members of Congress, are unwilling to take a stand and support the lives of newborns who survive an abortion attempt.
# --------------
#  : GOP Sen. John Cornyn is leading senators wanting to ban Chinese tech giant Huawei from supplying key parts of the U.S. energy…
# --------------
# Tomorrow, I’ll be hosting town halls in Emery and Carbon counties to hear from local residents. Join me at the Emery County Administration Building in Castle Dale at 3:00 PM, or the Carbon County Administration Building in Price at 4:30 PM. utpol
# --------------
# Under the previous administration,  stalled in removing 16 million tons of uranium tailings from Utah’s Colorado River Banks. Met with representatives of the Grand County and Moab City Councils to pledge my support for continued funding for the Moab UMTRA Project.
# --------------
#  : Fun fact: 149 years ago today Utah’s all-male territorial legislature UNANIMOUSLY voted for women’s suffrage. respect
# --------------
# The president’s speech was strong, well-delivered, and appealed to our patriotism and common values as Americans.
# --------------
#  : TUNE IN at 10:00 AM ET for the Senate health committee’s hearing on health centers and providers in underserved communities. Y…
# --------------
# It was an honor to meet Cornelius DeJong, a World War II veteran and one of the Greatest Generation. You can read more about his incredible navy service ⤵️
# --------------
# Rep. Tlaib took the politics of Washington deeper down the drain. Elected leaders should elevate, not degrade, our public discourse.
# --------------
# Happy birthday to the beautiful state of Utah!
# --------------
# With deep appreciation.
