# %% [markdown]
# # Project X

# %% [markdown]
# To download tweepy, open the terminal on jupyter notebook and write the following command: pip install tweepy

# %%
import csv
import json
import tweepy

# %%
twitter_cred = dict()

twitter_cred['CONSUMER_KEY'] = 'D6PekEtBw79hfFnma4sDBfhRd'
twitter_cred['CONSUMER_SECRET'] = 'BzQGGSrqxgugqHx9eUBOBi3IFTuM24LaMzjUm9xQ4dDz13lFuq'
twitter_cred['ACCESS_KEY'] = '990318274557693953-yF2TPznzOo4mkosJnaW0hOZoaUTehvE'
twitter_cred['ACCESS_SECRET'] = 'CANaiTLtBi3wUfp8E2M0D25Si5B8bXBYRIebm0HIGhxUr'

with open('twitter_credentials.json', 'w') as secret_info:
    json.dump(twitter_cred, secret_info, indent=4, sort_keys=True)

# %%
with open('twitter_credentials.json') as cred_data:
    info = json.load(cred_data)
consumer_key = info['CONSUMER_KEY']
consumer_secret = info['CONSUMER_SECRET']
access_key = info['ACCESS_KEY']
access_secret = info['ACCESS_SECRET']

# %%
def get_tweets(twitter_handle):
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_key, access_secret)
    api = tweepy.API(auth)
    
    tweets = []
    
    
    
    new_tweets = api.user_timeline(screen_name = twitter_handle, count = 200)
    tweets.extend(new_tweets)
    
    oldest_tweet = tweets[-1].id - 1
    
    while len(new_tweets) > 0:
        new_tweets = api.user_timeline(screen_name = twitter_handle, count = 200, max_id = oldest_tweet)
    
        print ('...%s tweets have been downloaded so far' % len(tweets))
        
        tweets.extend(new_tweets)
        oldest_tweet = tweets[-1].id - 1
    
    outtweets = [[tweet.id_str, tweet.created_at, tweet.text.encode('utf-8')] for tweet in tweets]
    
    with open('Tweets/' + twitter_handle + '_tweets.csv', 'w', encoding = 'utf8') as f:
            writer = csv.writer(f)
            writer.writerow(['id', 'created_at', 'text'])
            writer.writerows(outtweets)

# %%
for handle in handles[6:]:
    get_tweets(handle)
# Out:
# ...200 tweets have been downloaded so far
# ...400 tweets have been downloaded so far
# ...600 tweets have been downloaded so far
# ...800 tweets have been downloaded so far
# ...1000 tweets have been downloaded so far
# ...1200 tweets have been downloaded so far
# ...1400 tweets have been downloaded so far
# ...1600 tweets have been downloaded so far
# ...1800 tweets have been downloaded so far
# ...2000 tweets have been downloaded so far
# ...2200 tweets have been downloaded so far
# ...2400 tweets have been downloaded so far
# ...2600 tweets have been downloaded so far
# ...2800 tweets have been downloaded so far
# ...3000 tweets have been downloaded so far
# ...3200 tweets have been downloaded so far
# ...3202 tweets have been downloaded so far
# ...200 tweets have been downloaded so far
# ...400 tweets have been downloaded so far
# ...600 tweets have been downloaded so far
# ...800 tweets have been downloaded so far
# ...1000 tweets have been downloaded so far
# ...1200 tweets have been downloaded so far
# ...1400 tweets have been downloaded so far
# ...1600 tweets have been downloaded so far
# ...1800 tweets have been downloaded so far
# ...2000 tweets have been downloaded so far
# ...2200 tweets have been downloaded so far
# ...2400 tweets have been downloaded so far
# ...2600 tweets have been downloaded so far
# ...2800 tweets have been downloaded so far
# ...3000 tweets have been downloaded so far
# ...3200 tweets have been downloaded so far
# ...3246 tweets have been downloaded so far
# ...200 tweets have been downloaded so far
# ...400 tweets have been downloaded so far
# ...600 tweets have been downloaded so far
# ...800 tweets have been downloaded so far
# ...1000 tweets have been downloaded so far
# ...1200 tweets have been downloaded so far
# ...1400 tweets have been downloaded so far
# ...1600 tweets have been downloaded so far
# ...1800 tweets have been downloaded so far
# ...2000 tweets have been downloaded so far
# ...2200 tweets have been downloaded so far
# ...2400 tweets have been downloaded so far
# ...2600 tweets have been downloaded so far
# ...2800 tweets have been downloaded so far
# ...3000 tweets have been downloaded so far
# ...3200 tweets have been downloaded so far
# ...3207 tweets have been downloaded so far
# ...200 tweets have been downloaded so far
# ...400 tweets have been downloaded so far
# ...600 tweets have been downloaded so far
# ...800 tweets have been downloaded so far
# ...1000 tweets have been downloaded so far
# ...1200 tweets have been downloaded so far
# ...1400 tweets have been downloaded so far
# ...1600 tweets have been downloaded so far
# ...1800 tweets have been downloaded so far
# ...2000 tweets have been downloaded so far
# ...2199 tweets have been downloaded so far
# ...2399 tweets have been downloaded so far
# ...2599 tweets have been downloaded so far
# ...2798 tweets have been downloaded so far
# ...2998 tweets have been downloaded so far
# ...3198 tweets have been downloaded so far
# ...3218 tweets have been downloaded so far
# ...200 tweets have been downloaded so far
# ...400 tweets have been downloaded so far
# ...600 tweets have been downloaded so far
# ...800 tweets have been downloaded so far
# ...1000 tweets have been downloaded so far
# ...1200 tweets have been downloaded so far
# ...1400 tweets have been downloaded so far
# ...1599 tweets have been downloaded so far
# ...1799 tweets have been downloaded so far
# ...1999 tweets have been downloaded so far
# ...2199 tweets have been downloaded so far
# ...2399 tweets have been downloaded so far
# ...2598 tweets have been downloaded so far
# ...2798 tweets have been downloaded so far
# ...2998 tweets have been downloaded so far
# ...3198 tweets have been downloaded so far
# ...3219 tweets have been downloaded so far
# ...200 tweets have been downloaded so far
# ...400 tweets have been downloaded so far
# ...600 tweets have been downloaded so far
# ...799 tweets have been downloaded so far
# ...999 tweets have been downloaded so far
# ...1199 tweets have been downloaded so far
# ...1399 tweets have been downloaded so far
# ...1599 tweets have been downloaded so far
# ...1799 tweets have been downloaded so far
# ...1999 tweets have been downloaded so far
# ...2199 tweets have been downloaded so far
# ...2397 tweets have been downloaded so far
# ...2597 tweets have been downloaded so far
# ...2795 tweets have been downloaded so far
# ...2995 tweets have been downloaded so far
# ...3195 tweets have been downloaded so far
# ...3207 tweets have been downloaded so far
# ...200 tweets have been downloaded so far
# ...400 tweets have been downloaded so far
# ...600 tweets have been downloaded so far
# ...800 tweets have been downloaded so far
# ...1000 tweets have been downloaded so far
# ...1200 tweets have been downloaded so far
# ...1400 tweets have been downloaded so far
# ...1599 tweets have been downloaded so far
# ...1799 tweets have been downloaded so far
# ...1999 tweets have been downloaded so far
# ...2199 tweets have been downloaded so far
# ...2398 tweets have been downloaded so far
# ...2597 tweets have been downloaded so far
# ...2796 tweets have been downloaded so far
# ...2996 tweets have been downloaded so far
# ...3196 tweets have been downloaded so far
# ...3217 tweets have been downloaded so far
# ...200 tweets have been downloaded so far
# ...400 tweets have been downloaded so far
# ...600 tweets have been downloaded so far
# ...799 tweets have been downloaded so far
# ...999 tweets have been downloaded so far
# ...1196 tweets have been downloaded so far
# ...1396 tweets have been downloaded so far
# ...1596 tweets have been downloaded so far
# ...1793 tweets have been downloaded so far
# ...1992 tweets have been downloaded so far
# ...2192 tweets have been downloaded so far
# ...2392 tweets have been downloaded so far
# ...2592 tweets have been downloaded so far
# ...2792 tweets have been downloaded so far
# ...2992 tweets have been downloaded so far
# ...3192 tweets have been downloaded so far
# ...3219 tweets have been downloaded so far
# ...200 tweets have been downloaded so far
# ...400 tweets have been downloaded so far
# ...600 tweets have been downloaded so far
# ...800 tweets have been downloaded so far
# ...1000 tweets have been downloaded so far
# ...1200 tweets have been downloaded so far
# ...1399 tweets have been downloaded so far
# ...1599 tweets have been downloaded so far
# ...1799 tweets have been downloaded so far
# ...1999 tweets have been downloaded so far
# ...2199 tweets have been downloaded so far
# ...2398 tweets have been downloaded so far
# ...2598 tweets have been downloaded so far
# ...2798 tweets have been downloaded so far
# ...2998 tweets have been downloaded so far
# ...3198 tweets have been downloaded so far
# ...3239 tweets have been downloaded so far
# ...200 tweets have been downloaded so far
# ...400 tweets have been downloaded so far
# ...600 tweets have been downloaded so far
# ...799 tweets have been downloaded so far
# ...998 tweets have been downloaded so far
# ...1198 tweets have been downloaded so far
# ...1398 tweets have been downloaded so far
# ...1597 tweets have been downloaded so far
# ...1797 tweets have been downloaded so far
# ...1996 tweets have been downloaded so far
# ...2195 tweets have been downloaded so far
# ...2395 tweets have been downloaded so far
# ...2592 tweets have been downloaded so far
# ...2791 tweets have been downloaded so far
# ...2989 tweets have been downloaded so far
# ...3186 tweets have been downloaded so far
# ...3227 tweets have been downloaded so far
# ...200 tweets have been downloaded so far
# ...400 tweets have been downloaded so far
# ...600 tweets have been downloaded so far
# ...800 tweets have been downloaded so far
# ...1000 tweets have been downloaded so far
# ...1200 tweets have been downloaded so far
# ...1400 tweets have been downloaded so far
# ...1599 tweets have been downloaded so far
# ...1797 tweets have been downloaded so far
# ...1996 tweets have been downloaded so far
# ...2195 tweets have been downloaded so far
# ...2395 tweets have been downloaded so far
# ...2592 tweets have been downloaded so far
# ...2786 tweets have been downloaded so far
# ...2985 tweets have been downloaded so far
# ...3184 tweets have been downloaded so far
# ...3197 tweets have been downloaded so far
# ...200 tweets have been downloaded so far
# ...400 tweets have been downloaded so far
# ...600 tweets have been downloaded so far
# ...800 tweets have been downloaded so far
# ...1000 tweets have been downloaded so far
# ...1200 tweets have been downloaded so far
# ...1400 tweets have been downloaded so far
# ...1600 tweets have been downloaded so far
# ...1800 tweets have been downloaded so far
# ...2000 tweets have been downloaded so far
# ...2200 tweets have been downloaded so far
# ...2400 tweets have been downloaded so far
# ...2600 tweets have been downloaded so far
# ...2800 tweets have been downloaded so far
# ...3000 tweets have been downloaded so far
# ...3200 tweets have been downloaded so far
# ...3205 tweets have been downloaded so far
# ...200 tweets have been downloaded so far
# ...400 tweets have been downloaded so far
# ...600 tweets have been downloaded so far
# ...800 tweets have been downloaded so far
# ...1000 tweets have been downloaded so far
# ...1200 tweets have been downloaded so far
# ...1400 tweets have been downloaded so far
# ...1600 tweets have been downloaded so far
# ...1800 tweets have been downloaded so far
# ...1812 tweets have been downloaded so far
# ...200 tweets have been downloaded so far
# ...288 tweets have been downloaded so far
# ...200 tweets have been downloaded so far
# ...400 tweets have been downloaded so far
# ...598 tweets have been downloaded so far
# ...797 tweets have been downloaded so far
# ...995 tweets have been downloaded so far
# ...1195 tweets have been downloaded so far
# ...1395 tweets have been downloaded so far
# ...1594 tweets have been downloaded so far
# ...1793 tweets have been downloaded so far
# ...1991 tweets have been downloaded so far
# ...2031 tweets have been downloaded so far
# ...2034 tweets have been downloaded so far
# ...2043 tweets have been downloaded so far
# ...200 tweets have been downloaded so far
# ...400 tweets have been downloaded so far
# ...600 tweets have been downloaded so far
# ...800 tweets have been downloaded so far
# ...1000 tweets have been downloaded so far
# ...1200 tweets have been downloaded so far
# ...1400 tweets have been downloaded so far
# ...1600 tweets have been downloaded so far
# ...1800 tweets have been downloaded so far
# ...2000 tweets have been downloaded so far
# ...2199 tweets have been downloaded so far
# ...2399 tweets have been downloaded so far
# ...2599 tweets have been downloaded so far
# ...2799 tweets have been downloaded so far
# ...2999 tweets have been downloaded so far
# ...3198 tweets have been downloaded so far
# ...3231 tweets have been downloaded so far
# ...200 tweets have been downloaded so far
# ...400 tweets have been downloaded so far
# ...600 tweets have been downloaded so far
# ...800 tweets have been downloaded so far
# ...1000 tweets have been downloaded so far
# ...1200 tweets have been downloaded so far
# ...1400 tweets have been downloaded so far
# ...1600 tweets have been downloaded so far
# ...1800 tweets have been downloaded so far
# ...2000 tweets have been downloaded so far
# ...2200 tweets have been downloaded so far
# ...2400 tweets have been downloaded so far
# ...2600 tweets have been downloaded so far
# ...2800 tweets have been downloaded so far
# ...3000 tweets have been downloaded so far
# ...3200 tweets have been downloaded so far
# ...3231 tweets have been downloaded so far
# ...200 tweets have been downloaded so far
# ...400 tweets have been downloaded so far
# ...600 tweets have been downloaded so far
# ...800 tweets have been downloaded so far
# ...1000 tweets have been downloaded so far
# ...1200 tweets have been downloaded so far
# ...1399 tweets have been downloaded so far
# ...1598 tweets have been downloaded so far
# ...1798 tweets have been downloaded so far
# ...1998 tweets have been downloaded so far
# ...2198 tweets have been downloaded so far
# ...2398 tweets have been downloaded so far
# ...2598 tweets have been downloaded so far
# ...2773 tweets have been downloaded so far

# %%
politicians = ["Mitt Romey", "Boris Johnson", "Donald Trump", "Bernie Sanders", "Joe Biden", "Elizabeth Warren",
               "Kamala Harris", "Pete Buttigieg", "Cory Booker", "Beto O' Rourke", "Andrew Yang", "Ben Sasse", 
               "Ted Cruz", "Mitt Romney", "Mark Cuban", "Mike Pence", "Jeff Flake"]

handles = ["MittRomey", "BorisJohnson", "realDonaldTrump", "BernieSanders", "SenSanders", "JoeBiden", "ewarren",
           "SenWarren", "KamalaHarris", "SenKamalaHarris", "PeteButtigieg", "CoryBooker", "SenBooker", "BetoORourke",
           "AndrewYang", "BenSasse", "TedCruz", "SenTedCruz", "MittRomney", "SenatorRomney", "mcuban", "mike_pence", 
           "VP", "JeffFlake"]
