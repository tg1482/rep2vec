# %%
% matplotlib inline

from __future__ import division

import numpy as np 
import pandas as pd 

import tweepy
from nltk.tokenize import TweetTokenizer

import re
from collections import Counter
from nltk.tokenize import TweetTokenizer

import json
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
! ls
# %cd '/content/drive/My Drive/Colab Notebooks/Summer 2020/Project-X/'
! ls
# Out:
# drive  sample_data
# /content/drive/My Drive/Colab Notebooks/Summer 2020/Project-X
# data-pull.ipynb				     README.md
# Data_Utilities.py			     relevant-tweets-buckets.ipynb
# initial-analysis.ipynb			     relevant-tweets-optimization.ipynb
# LM.ipynb				     Research
# ProjectX_Sentiment_Analysis_GoogleAPI.ipynb  Tweets
# __pycache__				     twitter_credentials.json

# %%
def tweets_call(twitter_handle):

    with open('twitter_credentials.json') as cred_data:
            info = json.load(cred_data)
    consumer_key = info['CONSUMER_KEY']
    consumer_secret = info['CONSUMER_SECRET']
    access_key = info['ACCESS_KEY']
    access_secret = info['ACCESS_SECRET']
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_key, access_secret)
    api = tweepy.API(auth)
    
    try:
      tweets = get_tweets(twitter_handle)
      most_recent_tweet = tweets.iloc[0][0] + 1
      tweets_bunch = 'init'
      new_tweets = []

      while len(tweets_bunch) > 0:
        tweets_bunch = api.user_timeline(screen_name = twitter_handle, count = 200, since_id = most_recent_tweet, tweet_mode = "extended")
        new_tweets.extend(tweets_bunch)
        new_num = len(new_tweets)
        print ('...{a} tweets have been downloaded for {b}'.format(a = new_num, b = twitter_handle))
        try: 
          most_recent_tweet = new_tweets[0].id + 1
        except IndexError:
          return
        
      outtweets = [[tweet.id, tweet.created_at, tweet.full_text] for tweet in new_tweets]
      df = pd.concat([pd.DataFrame(outtweets, columns=['id', 'created_at', 'text']), tweets], ignore_index=True)

    except FileNotFoundError:
      new_tweets = api.user_timeline(screen_name = twitter_handle, count = 200, tweet_mode = "extended")
      new_num = len(new_tweets)
      print ('...{a} tweets have been downloaded for {b}'.format(a = new_num, b = twitter_handle))
      outtweets = [[tweet.id_str, tweet.created_at, tweet.full_text] for tweet in new_tweets]
      df = pd.DataFrame(outtweets, columns=['id', 'created_at', 'text'])

    df.to_csv('Tweets/' + twitter_handle + '_tweets.csv', index=False, encoding = 'utf8')
            
def get_tweets(twitter_handle):
    tweet_data = pd.read_csv('Tweets/' + twitter_handle + '_tweets.csv', encoding = 'utf-8')
    tweet_data = tweet_data.dropna()
    return tweet_data

def get_old_tweets(twitter_handle, n=200):

    with open('twitter_credentials.json') as cred_data:
            info = json.load(cred_data)
    consumer_key = info['CONSUMER_KEY']
    consumer_secret = info['CONSUMER_SECRET']
    access_key = info['ACCESS_KEY']
    access_secret = info['ACCESS_SECRET']
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_key, access_secret)
    api = tweepy.API(auth)
    
    try:
      tweets = get_tweets(twitter_handle)
      first_tweet = tweets.iloc[-1][0] - 1
      new_tweets = []
      num = 0

      while num <= n:
        tweets_bunch = api.user_timeline(screen_name = twitter_handle, count = n - num, max_id = first_tweet, tweet_mode = "extended")
        new_tweets.extend(tweets_bunch)
        new_num = len(new_tweets)
        print ('...{a} tweets have been downloaded for {b}'.format(a = new_num, b = twitter_handle))
        try: 
          first_tweet = new_tweets[-1].id + 1
        except IndexError:
          return
        num += new_num
        
      outtweets = [[tweet.id, tweet.created_at, tweet.full_text] for tweet in new_tweets]
      df = pd.concat([tweets, pd.DataFrame(outtweets, columns=['id', 'created_at', 'text'])], ignore_index=True)
      df.to_csv('Tweets/' + twitter_handle + '_tweets.csv', index=False, encoding = 'utf8')

    except FileNotFoundError:
        tweets_call(twitter_handle)


# tweets = get_tweets('SenBooker')

# %%
reps = ["ChuckGrassley", "jaredpolis", "clairecmc", "GovChristie", "jahimes", "MayorMark", "GovGaryJohnson", "RepSteveIsrael", "SteveWorks4You", "JerryBrownGov", "PeterRoskam", "RepCohen", 
               "AndrewYang", "BenSasse", "BernieSanders", "BorisJohnson", "CoryBooker", "JeffFlake", "JoeBiden", "KamalaHarris", "MittRomney", "PeteButtigieg", "SenBooker", "SenKamalaHarris", 
               "SenSanders", "SenTedCruz", "SenWarren", "SenatorRomney", "TedCruz", "ewarren", "mcuban", "mike_pence", "realDonaldTrump"]

# %%
for rep in reps:
  # tweets_call(rep)
  get_old_tweets(rep, 200)
# Out:
# ...200 tweets have been downloaded for ChuckGrassley
# ...220 tweets have been downloaded for ChuckGrassley
# ...200 tweets have been downloaded for jaredpolis
# ...220 tweets have been downloaded for jaredpolis
# ...200 tweets have been downloaded for clairecmc
# ...220 tweets have been downloaded for clairecmc
# ...199 tweets have been downloaded for GovChristie
# ...200 tweets have been downloaded for GovChristie
# ...200 tweets have been downloaded for jahimes
# ...220 tweets have been downloaded for jahimes
# ...198 tweets have been downloaded for MayorMark
# ...200 tweets have been downloaded for MayorMark
# ...200 tweets have been downloaded for GovGaryJohnson
# ...220 tweets have been downloaded for GovGaryJohnson
# ...200 tweets have been downloaded for RepSteveIsrael
# ...220 tweets have been downloaded for RepSteveIsrael
# ...185 tweets have been downloaded for SteveWorks4You
# ...199 tweets have been downloaded for SteveWorks4You
# ...200 tweets have been downloaded for JerryBrownGov
# ...220 tweets have been downloaded for JerryBrownGov
# ...200 tweets have been downloaded for PeterRoskam
# ...220 tweets have been downloaded for PeterRoskam
# ...199 tweets have been downloaded for RepCohen
# ...200 tweets have been downloaded for RepCohen
# ...0 tweets have been downloaded for AndrewYang
# ...0 tweets have been downloaded for BenSasse
# ...0 tweets have been downloaded for BernieSanders
# ...0 tweets have been downloaded for BorisJohnson
# ...0 tweets have been downloaded for CoryBooker
# ...0 tweets have been downloaded for JeffFlake
# ...0 tweets have been downloaded for JoeBiden
# ...0 tweets have been downloaded for KamalaHarris
# ...0 tweets have been downloaded for MittRomney
# ...0 tweets have been downloaded for PeteButtigieg
# ...0 tweets have been downloaded for SenBooker
# ...0 tweets have been downloaded for SenKamalaHarris
# ...0 tweets have been downloaded for SenSanders
# ...0 tweets have been downloaded for SenTedCruz
# ...0 tweets have been downloaded for SenWarren
# ...0 tweets have been downloaded for SenatorRomney
# ...0 tweets have been downloaded for TedCruz
# ...200 tweets have been downloaded for ewarren
# ...220 tweets have been downloaded for ewarren
# ...200 tweets have been downloaded for mcuban
# ...220 tweets have been downloaded for mcuban
# ...0 tweets have been downloaded for mike_pence
# ...0 tweets have been downloaded for realDonaldTrump

# %% [markdown]
# Downloaded tweets till here. Building Language Model now.

# %%
from fastai.text import *

data_path = Path('Tweets')
model_path = Path(os.getcwd())
bs = 48

# %%
train_df = pd.DataFrame()
for rep in reps:
  rep_df = get_tweets(rep)
  rep_df['rep'] = [rep]*len(rep_df)
  train_df = pd.concat([rep_df, train_df], ignore_index=True)

# %%
train_df.text[3]
# Out:
# ' @TeamTrump: Mail-In Ballots will lead to MASSIVE electoral fraud and a RIGGED 2020 Election.\n\nWe cannot let it happen! '

# %%
train_df.text = train_df.text.apply(lambda x: re.sub(u'(https?:)\/\/\S*', u'', x))    # Removing 'https://'
train_df.text = train_df.text.apply(lambda x: re.sub(u'RT', u'', x))                  # Changing 'RT' to ''
train_df.text = train_df.text.apply(lambda x: re.sub(u'\&amp\;', u'and', x))          # Changing '&amp;' to 'and'

# %% [markdown]
# Need to find a way to mark a tweet as a RT or remove the RT altogether since the RT may not necessarily be a reflection of the tweeter's opinion but could also be a critique which not be correctly reflected.

# %%
# data_lm = (TextList.from_df(path = data_path, df = train_df, cols = 2)
#             .split_by_rand_pct(0.1)
#             .label_for_lm()           
#             .databunch(bs=bs))
# data_lm.save('data_lm.pk1')
data_lm = load_data(data_path, 'data_lm.pkl')

# %%
data_lm.show_batch()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>idx</th>
#       <th>text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>xxmaj immigration , xxmaj drugs and xxmaj crime . xxbos xxup icymi : “ xxmaj jeff xxmaj sessions to federal prosecutors : i do n’t trust you ” xxbos @cbsnews : xxup watch xxup live : xxmaj sen. xxmaj bernie xxmaj sanders to unveil his “ xxmaj medicare for all ” health care plan xxbos @marklevinshow : xxmaj sen. xxmaj mike xxmaj lee exposes xxmaj democrat xxmaj party .</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>make xxmaj america xxmaj great xxmaj again # xxmaj debates2016 # xxup maga xxbos xxmaj xxunk the xxup gop believe the single most important issue facing our nation is to let employers deny women access to birth control coverage . xxbos xxup democrat xxup congressional xxup hearings xxup are # xxup rigged ! xxbos xxmaj great win by xxunk yesterday . # xxunk xxbos @sarahksilverman : xxmaj it ’s because</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>un xxmaj human xxmaj rights xxmaj council should turn its focus to the serious human rights violations happening in xxmaj china , xxmaj venezuela , and xxmaj cuba – its members ' own countries – instead of pushing anti - xxmaj american policies . xxbos xxmaj in 1981 , i won my first election to become xxmaj mayor of xxmaj burlington by 10 votes . xxmaj please remember that every</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>\n  xxbos xxmaj conservative leaders like xxunk will get this country back on track . xxmaj missouri , vote for xxmaj roy on xxmaj nov. 8th # xxup xxunk xxbos @itsmepv xxmaj what ! ! ? ? xxmaj you ca n't leave . xxbos xxmaj would be glad to go on xxup msnbc or any other network too . xxmaj enjoyed xxup cnn and xxmaj business xxmaj insider .</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>deserve safety , dignity , and a voice on the job . xxmaj during a xxunk … xxbos xxunk @sbagov xxmaj the goal was to keep people on the payrolls . xxmaj if funded immediately , it might have . xxmaj but the delay led to layoffs , which along with xxmaj stay xxmaj at xxmaj home led to a collapse in consumer demand and 36 m unemployed . xxmaj</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Language Model Training on Twitter Data

# %%
learn_lm = language_model_learner(data_lm, AWD_LSTM, drop_mult=0.3)

# %%
learn_lm.lr_find()
learn_lm.recorder.plot(suggestion=True)
min_grad_lr = learn_lm.recorder.min_grad_lr
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='99' class='' max='626' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       15.81% [99/626 00:18<01:37 11.1222]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 4.79E-02
# Min loss divided by 10: 1.74E-02

# %%
learn_lm.fit_one_cycle(1, slice(1e-2,1e-1), moms=(0.8,0.7))
learn_lm.save('learn_lm_v1')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.358604</td>
#       <td>4.096649</td>
#       <td>0.295712</td>
#       <td>01:59</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn_lm.freeze_to(-2)
learn_lm.fit_one_cycle(1, slice(1e-3,1e-1), moms=(0.8,0.7))
learn_lm.save('learn_lm_v2')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.008318</td>
#       <td>3.848891</td>
#       <td>0.319551</td>
#       <td>02:04</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn_lm.unfreeze()
learn_lm.lr_find()
learn_lm.recorder.plot(skip_end=15)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='98' class='' max='626' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       15.65% [98/626 00:22<01:58 14.5224]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn_lm.unfreeze()
learn_lm.fit_one_cycle(5, slice(1e-4,1e-3), moms=(0.8,0.7))
learn_lm.save('learn_lm_v3')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.678654</td>
#       <td>3.806829</td>
#       <td>0.324958</td>
#       <td>02:26</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.611075</td>
#       <td>3.736622</td>
#       <td>0.333447</td>
#       <td>02:26</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.513739</td>
#       <td>3.697960</td>
#       <td>0.338787</td>
#       <td>02:26</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.427234</td>
#       <td>3.685868</td>
#       <td>0.340904</td>
#       <td>02:27</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>3.406071</td>
#       <td>3.687043</td>
#       <td>0.340996</td>
#       <td>02:27</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn_lm.lr_find()
learn_lm.recorder.plot(skip_end=15)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='95' class='' max='626' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       15.18% [95/626 00:21<01:59 12.0245]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn_lm.save('learn_lm_final')

# %%
TEXT = "Food should be accessible"
N_WORDS = 40
N_SENTENCES = 2

# %%
print("\n".join(learn_lm.predict(TEXT, N_WORDS, temperature=0.75) for _ in range(N_SENTENCES)))
# Out:
# Food should be accessible for the American people , but EQUAL TREATMENT ARE IN JAIL AND THAT HELPS TO THE EVERY WAY xxbos In this country , our government
# Food should be accessible away from the right and left . We can do more to reduce the prices on people who are struggling .
#
#   Watch live now : xxbos The Senate Judiciary Committee just voted to

# %%
learn_lm.save('learn_lm_final')
learn_lm.save_encoder('fine_tuned_enc')

# %% [markdown]
# ## Classification of Tweets by Rep to extract Rep-Embedding

# %% [markdown]
# Trying to classify tweets into

# %%
from collections import Counter

Counter(train_df.rep)
# Out:
# Counter({'AndrewYang': 3537,
#          'BenSasse': 3227,
#          'BernieSanders': 3447,
#          'BorisJohnson': 2068,
#          'ChuckGrassley': 1229,
#          'CoryBooker': 3421,
#          'GovChristie': 1202,
#          'GovGaryJohnson': 1221,
#          'JeffFlake': 2866,
#          'JerryBrownGov': 1214,
#          'JoeBiden': 2115,
#          'KamalaHarris': 3444,
#          'MayorMark': 1215,
#          'MittRomney': 1927,
#          'PeteButtigieg': 3446,
#          'PeterRoskam': 1220,
#          'RepCohen': 1210,
#          'RepSteveIsrael': 1222,
#          'SenBooker': 3425,
#          'SenKamalaHarris': 3438,
#          'SenSanders': 3453,
#          'SenTedCruz': 3463,
#          'SenWarren': 3433,
#          'SenatorRomney': 498,
#          'SteveWorks4You': 1116,
#          'TedCruz': 3516,
#          'clairecmc': 1264,
#          'ewarren': 1244,
#          'jahimes': 1220,
#          'jaredpolis': 1230,
#          'mcuban': 1248,
#          'mike_pence': 3490,
#          'realDonaldTrump': 1335})

# %%
reps_for_clas = ["BernieSanders", "JoeBiden", "MittRomney", "SenKamalaHarris", "SenTedCruz", "SenWarren", "SenatorRomney", "mcuban", "mike_pence", "realDonaldTrump"]
df_clas = train_df.loc[train_df.rep.apply(lambda rep: rep in reps_for_clas)]

# %%
df_clas
# Out:
#                         id  ...              rep
# 0      1279649292966395904  ...  realDonaldTrump
# 1      1279623260490039298  ...  realDonaldTrump
# 2      1279621608521547776  ...  realDonaldTrump
# 3      1279611869515440129  ...  realDonaldTrump
# 4      1279545900138991617  ...  realDonaldTrump
# ...                    ...  ...              ...
# 51272   835209701457526784  ...    BernieSanders
# 51273   835172577345699840  ...    BernieSanders
# 51274   834818062339756032  ...    BernieSanders
# 51275   834807788828233729  ...    BernieSanders
# 51276   834598970198470657  ...    BernieSanders
#
# [24394 rows x 4 columns]

# %%
data_lm.vocab.itos
# Out:
# ['xxunk',
#  'xxpad',
#  'xxbos',
#  'xxeos',
#  'xxfld',
#  'xxmaj',
#  'xxup',
#  'xxrep',
#  'xxwrep',
#  '.',
#  'the',
#  'to',
#  ',',
#  'and',
#  'of',
#  ':',
#  'a',
#  'in',
#  'for',
#  '#',
#  'is',
#  'we',
#  'i',
#  'on',
#  'that',
#  'this',
#  'it',
#  'our',
#  '…',
#  '-',
#  '’s',
#  'you',
#  '!',
#  'with',
#  'are',
#  'be',
#  "'s",
#  'at',
#  'have',
#  '\n \n ',
#  'will',
#  'not',
#  'from',
#  '"',
#  '\n ',
#  'my',
#  'today',
#  'as',
#  'all',
#  'people',
#  'who',
#  'by',
#  'they',
#  'their',
#  'do',
#  'about',
#  'has',
#  'more',
#  'an',
#  '?',
#  'can',
#  'trump',
#  'he',
#  'us',
#  'was',
#  'but',
#  'his',
#  'your',
#  'n’t',
#  'up',
#  '—',
#  'what',
#  '“',
#  'president',
#  'if',
#  'now',
#  'out',
#  'must',
#  'should',
#  '/',
#  'need',
#  'no',
#  'great',
#  'new',
#  'just',
#  'time',
#  'one',
#  'country',
#  'so',
#  'health',
#  '”',
#  'make',
#  'would',
#  'or',
#  'get',
#  "n't",
#  'care',
#  'bill',
#  'day',
#  'when',
#  'thank',
#  'american',
#  'americans',
#  'there',
#  '$',
#  'me',
#  'here',
#  'work',
#  'america',
#  'right',
#  'than',
#  'like',
#  'how',
#  'senate',
#  'been',
#  'act',
#  'vote',
#  'support',
#  'over',
#  'every',
#  'congress',
#  'let',
#  'them',
#  ')',
#  'back',
#  'fight',
#  'help',
#  '...',
#  'state',
#  '(',
#  '–',
#  'women',
#  'live',
#  'first',
#  'years',
#  'thanks',
#  'why',
#  'join',
#  'see',
#  'these',
#  'families',
#  'good',
#  'many',
#  'w',
#  'tax',
#  'last',
#  '@realdonaldtrump',
#  'working',
#  'justice',
#  'those',
#  'know',
#  'workers',
#  'her',
#  'take',
#  '’m',
#  'watch',
#  'going',
#  'against',
#  'house',
#  'year',
#  'proud',
#  'want',
#  "'",
#  'because',
#  'go',
#  'only',
#  'way',
#  'nation',
#  'into',
#  '@corybooker',
#  'end',
#  'family',
#  'big',
#  'tonight',
#  'government',
#  'rights',
#  'ca',
#  'world',
#  'after',
#  '%',
#  'keep',
#  'change',
#  'were',
#  'does',
#  'most',
#  '’re',
#  'public',
#  '--',
#  'stand',
#  'some',
#  'federal',
#  'had',
#  'its',
#  'states',
#  'together',
#  'being',
#  'administration',
#  'jobs',
#  'cruz',
#  'campaign',
#  'forward',
#  'stop',
#  '👍',
#  '1',
#  'law',
#  "'re",
#  'did',
#  'am',
#  'better',
#  'could',
#  'plan',
#  'national',
#  'down',
#  'other',
#  'pay',
#  'made',
#  '>',
#  '2',
#  'still',
#  'very',
#  'protect',
#  "'m",
#  'much',
#  'before',
#  'which',
#  'week',
#  'him',
#  'senator',
#  'everyone',
#  'where',
#  'too',
#  'texas',
#  'economy',
#  'any',
#  'lives',
#  'never',
#  'life',
#  'crisis',
#  'u.s.',
#  'system',
#  'next',
#  '4',
#  'important',
#  'across',
#  'million',
#  '’',
#  'even',
#  'security',
#  'future',
#  '’ve',
#  'children',
#  'community',
#  'again',
#  'got',
#  'best',
#  'she',
#  'come',
#  'history',
#  'election',
#  'republicans',
#  'ted',
#  'job',
#  'continue',
#  '@govpencein',
#  'off',
#  'united',
#  'say',
#  'fighting',
#  'home',
#  'think',
#  'while',
#  'news',
#  'free',
#  'students',
#  'real',
#  'love',
#  'well',
#  'court',
#  'hope',
#  'look',
#  'morning',
#  'millions',
#  'call',
#  'long',
#  'another',
#  'please',
#  'tomorrow',
#  'sen.',
#  'war',
#  'give',
#  'political',
#  'pass',
#  '🇺',
#  'put',
#  '🇸',
#  'under',
#  'happy',
#  'also',
#  'leadership',
#  'money',
#  'during',
#  'may',
#  'sure',
#  'white',
#  'needs',
#  'said',
#  'via',
#  'border',
#  'policy',
#  'violence',
#  '3',
#  'since',
#  'read',
#  'full',
#  'night',
#  'two',
#  'making',
#  'talk',
#  'california',
#  'kavanaugh',
#  'ago',
#  'school',
#  'through',
#  'economic',
#  'legislation',
#  'doing',
#  'honor',
#  'black',
#  '’ll',
#  'days',
#  'communities',
#  'office',
#  'democrats',
#  "'ve",
#  'win',
#  'power',
#  'south',
#  'iran',
#  'climate',
#  'republican',
#  'believe',
#  'deal',
#  'ever',
#  'clear',
#  'tune',
#  'safe',
#  'city',
#  'leaders',
#  'gun',
#  'says',
#  'hard',
#  'education',
#  'medicare',
#  'ensure',
#  'military',
#  'iowa',
#  'getting',
#  "'ll",
#  'without',
#  'companies',
#  'class',
#  'kids',
#  'away',
#  'deserve',
#  'reform',
#  'always',
#  'looking',
#  'enough',
#  'step',
#  '5',
#  'around',
#  'own',
#  'human',
#  'friends',
#  'done',
#  'service',
#  'part',
#  'use',
#  'freedom',
#  'congratulations',
#  'strong',
#  'same',
#  'voting',
#  'wo',
#  'coming',
#  'then',
#  'access',
#  'obama',
#  'team',
#  'democracy',
#  'biden',
#  'yesterday',
#  'bipartisan',
#  'young',
#  'friend',
#  'pm',
#  'rally',
#  'action',
#  'police',
#  'wall',
#  'meet',
#  'indiana',
#  'gop',
#  'discuss',
#  'bring',
#  'wage',
#  'middle',
#  'members',
#  '@tedcruz',
#  'find',
#  'social',
#  '10',
#  'special',
#  'thing',
#  'place',
#  'local',
#  'billion',
#  'safety',
#  '😀',
#  'open',
#  'supreme',
#  'https',
#  'remember',
#  'both',
#  'hearing',
#  'high',
#  'politics',
#  'until',
#  'address',
#  'governor',
#  'passed',
#  'business',
#  'colleagues',
#  'debt',
#  'few',
#  'issues',
#  'meeting',
#  'washington',
#  'introduced',
#  'party',
#  'really',
#  'hear',
#  'thousands',
#  'mayor',
#  '‘',
#  'speak',
#  'lost',
#  'report',
#  'trade',
#  'show',
#  'drug',
#  'top',
#  'grateful',
#  'democratic',
#  'left',
#  'debate',
#  'taking',
#  '@senbooker',
#  'including',
#  'record',
#  'things',
#  'town',
#  '@sentedcruz',
#  'yes',
#  'trying',
#  'nothing',
#  'foreign',
#  'provide',
#  'donald',
#  '+',
#  'cut',
#  'start',
#  'tell',
#  'men',
#  'month',
#  'story',
#  'small',
#  'build',
#  'hall',
#  'wrong',
#  'coronavirus',
#  'create',
#  'insurance',
#  'lead',
#  'energy',
#  'income',
#  'ready',
#  'yet',
#  'china',
#  'glad',
#  'corporations',
#  'veterans',
#  'committee',
#  'cuts',
#  'agree',
#  'everything',
#  'joining',
#  'between',
#  'wants',
#  'already',
#  'voted',
#  'past',
#  'paid',
#  'vp',
#  'anti',
#  'man',
#  'critical',
#  'txsen',
#  'sign',
#  'share',
#  'moment',
#  'fair',
#  'something',
#  'living',
#  'welcome',
#  '.@corybooker',
#  'uk',
#  'stay',
#  'attack',
#  'decision',
#  'instead',
#  'efforts',
#  'person',
#  'save',
#  'program',
#  'speech',
#  '15',
#  'student',
#  'able',
#  'college',
#  'issue',
#  'county',
#  'soon',
#  'affordable',
#  'russia',
#  'talking',
#  'order',
#  'far',
#  'serve',
#  'former',
#  'hold',
#  'honored',
#  'move',
#  'less',
#  'criminal',
#  'nj',
#  'general',
#  'opportunity',
#  'investigation',
#  'makes',
#  'having',
#  'leader',
#  'spending',
#  'lot',
#  '*',
#  'teachers',
#  'means',
#  '6',
#  'funding',
#  '@petebuttigieg',
#  'speaking',
#  'john',
#  'presidential',
#  'judge',
#  'taxes',
#  'face',
#  'someone',
#  'civil',
#  'keeptexasred',
#  'times',
#  '7',
#  '@berniesanders',
#  'running',
#  'mueller',
#  'water',
#  'movement',
#  '@sensanders',
#  '2020',
#  'case',
#  'others',
#  'immigration',
#  'budget',
#  'major',
#  'force',
#  'raise',
#  'businesses',
#  'bend',
#  'old',
#  'dr.',
#  'policies',
#  'question',
#  'truth',
#  'check',
#  'powerful',
#  ';',
#  'called',
#  'child',
#  'visit',
#  're',
#  'danbury',
#  'met',
#  '@bensasse',
#  'bernie',
#  'food',
#  'each',
#  'control',
#  'line',
#  'officials',
#  'senators',
#  'parents',
#  'accountable',
#  'continues',
#  'media',
#  'true',
#  'supporting',
#  'excited',
#  'bad',
#  'risk',
#  'celebrate',
#  'response',
#  'single',
#  'seen',
#  'housing',
#  'fbi',
#  'ban',
#  'listen',
#  'whether',
#  'relief',
#  'choice',
#  '️',
#  'questions',
#  'fact',
#  'street',
#  'nomination',
#  'video',
#  'marijuana',
#  'et',
#  'nearly',
#  'candidate',
#  'pandemic',
#  'statement',
#  '8',
#  'hour',
#  'industry',
#  'works',
#  'cost',
#  '@gop',
#  'afford',
#  'low',
#  'colorado',
#  'book',
#  'allow',
#  'elections',
#  'floor',
#  'run',
#  'joined',
#  'schools',
#  'co',
#  'benefits',
#  'led',
#  'booker',
#  'asked',
#  'israel',
#  'union',
#  'values',
#  'voters',
#  'such',
#  'anyone',
#  'congrats',
#  'corporate',
#  'become',
#  'little',
#  'took',
#  'global',
#  'nominee',
#  'race',
#  'matter',
#  'used',
#  'message',
#  'victims',
#  'amendment',
#  '9',
#  'leave',
#  'secretary',
#  'sanders',
#  'behind',
#  'interview',
#  'idea',
#  'heart',
#  'close',
#  'air',
#  'death',
#  'happen',
#  'wages',
#  'possible',
#  'resources',
#  'event',
#  'clean',
#  'level',
#  'threat',
#  'huge',
#  'healthcare',
#  'months',
#  'three',
#  'jersey',
#  '100',
#  'heard',
#  'once',
#  'voter',
#  'costs',
#  'de',
#  'minimum',
#  'words',
#  'incredible',
#  'comes',
#  'helping',
#  'thoughts',
#  'early',
#  'm',
#  'staff',
#  'financial',
#  'serious',
#  'november',
#  'latest',
#  'covid-19',
#  'dollars',
#  'hate',
#  'process',
#  'follow',
#  'based',
#  'came',
#  'racial',
#  'employees',
#  'standing',
#  'puerto',
#  'folks',
#  'elected',
#  'facebook',
#  'historic',
#  'mr.',
#  'chance',
#  'side',
#  'birthday',
#  'set',
#  'failed',
#  'kind',
#  'common',
#  'wait',
#  'basic',
#  'center',
#  'banks',
#  'dc',
#  'woman',
#  'demand',
#  'impact',
#  'cory',
#  'weekend',
#  'loved',
#  'resolution',
#  'game',
#  'joe',
#  '@barackobama',
#  'north',
#  'told',
#  'courage',
#  'calling',
#  '2018',
#  'defense',
#  'worth',
#  'data',
#  'ahead',
#  'answer',
#  'rule',
#  'enforcement',
#  'hours',
#  'letter',
#  'voice',
#  'sense',
#  'reason',
#  'finally',
#  'actually',
#  'learn',
#  'ask',
#  'candidates',
#  'higher',
#  'half',
#  'signed',
#  'laws',
#  'immediately',
#  'covid19',
#  't',
#  'nuclear',
#  'commitment',
#  'paying',
#  'company',
#  'promise',
#  'constitution',
#  'george',
#  'dems',
#  'using',
#  'increase',
#  'progress',
#  '\xa0',
#  'bills',
#  'giving',
#  'protecting',
#  'leading',
#  'dreamers',
#  'enjoyed',
#  'color',
#  'forget',
#  'growth',
#  'effort',
#  '20',
#  'infrastructure',
#  'emergency',
#  'agenda',
#  'victory',
#  'wealth',
#  'coverage',
#  'medical',
#  'try',
#  'press',
#  'four',
#  'problem',
#  'point',
#  'fought',
#  'az',
#  'expand',
#  'equality',
#  'maga',
#  'crime',
#  'attacks',
#  'held',
#  'needed',
#  'citizens',
#  'equal',
#  'tour',
#  'dangerous',
#  'amazing',
#  'passing',
#  'dignity',
#  'private',
#  'hundreds',
#  'rico',
#  'lose',
#  'term',
#  'defend',
#  'turn',
#  '30',
#  'ones',
#  'twitter',
#  'number',
#  'interests',
#  'spent',
#  'hands',
#  'break',
#  'worked',
#  'attorney',
#  'ed',
#  'information',
#  '11',
#  'breaking',
#  'icymi',
#  'king',
#  'texans',
#  'rate',
#  'head',
#  'medicaid',
#  'generation',
#  'seeing',
#  'respect',
#  'universal',
#  'mexico',
#  'entire',
#  '@mike_pence',
#  'elect',
#  'march',
#  'shutdown',
#  'anything',
#  'crowd',
#  'role',
#  'hurricane',
#  'discussion',
#  'calls',
#  'send',
#  'understand',
#  'unemployment',
#  'killed',
#  'congressional',
#  'immigrants',
#  'protections',
#  'almost',
#  'drugs',
#  'conversation',
#  'barr',
#  'ballot',
#  'rules',
#  'especially',
#  'fix',
#  'bank',
#  'plans',
#  'saying',
#  'conservative',
#  'announced',
#  'conditions',
#  'gov',
#  'quality',
#  'massive',
#  'johnson',
#  'legal',
#  'arizona',
#  'el',
#  'yemen',
#  'disaster',
#  'department',
#  'happening',
#  'mike',
#  'pleased',
#  'society',
#  'scotus',
#  'deeply',
#  '@',
#  'word',
#  'prevent',
#  'discrimination',
#  'cases',
#  'truly',
#  'choose',
#  'space',
#  'assault',
#  'along',
#  'reality',
#  'programs',
#  'dream',
#  '2016',
#  'moral',
#  'countries',
#  'utah',
#  'officers',
#  'credit',
#  'yanggang',
#  'majority',
#  'services',
#  'wealthy',
#  'tuesday',
#  'admin',
#  'farmers',
#  'improve',
#  'billionaires',
#  'trillion',
#  'different',
#  'repeal',
#  'daca',
#  'putting',
#  'secure',
#  'fellow',
#  'personal',
#  'introduce',
#  'lower',
#  'gets',
#  '@msnbc',
#  'gave',
#  'missed',
#  'toward',
#  'anniversary',
#  'abuse',
#  'breaks',
#  'spoke',
#  'often',
#  'actions',
#  'rest',
#  'growing',
#  'saudi',
#  'second',
#  'weapons',
#  'helped',
#  'brett',
#  'san',
#  'interest',
#  'ending',
#  'fire',
#  'pres',
#  'capitol',
#  'profits',
#  'goes',
#  'looks',
#  'shows',
#  'sexual',
#  'brave',
#  'feel',
#  'broken',
#  'weeks',
#  'committed',
#  '@potus',
#  'ceo',
#  'available',
#  'ct',
#  '12',
#  'afternoon',
#  ...]

# %%
# data_clas = (TextList.from_df(path = data_path, df = df_clas, cols = 2, vocab=data_lm.vocab)
#             .split_by_rand_pct(0.1)
#             .label_from_df(cols=3)           
#             .databunch(bs=bs))
# data_clas.save('data_clas.pkl')
data_clas = load_data(data_path, 'data_clas.pkl', bs=16)

# %%
data_clas.show_batch()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>text</th>
#       <th>target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>xxbos xxmaj george xxmaj floyd \n  xxmaj ahmaud xxmaj arbery \n  xxmaj breonna xxmaj taylor \n  xxmaj michael xxmaj brown \n  xxmaj trayvon xxmaj martin \n  xxmaj eric xxmaj garner \n  xxmaj philando xxmaj xxunk \n  xxmaj sandra xxmaj bland \n  xxmaj xxunk mcdonald \n  xxmaj tamir xxmaj rice \n  xxmaj jordan xxmaj davis \n  xxmaj alton xxmaj sterling</td>
#       <td>SenKamalaHarris</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj bernie xxmaj sanders , “ xxmaj the xxmaj economy is doing well , and i ’m sure i do n’t have to give xxmaj trump any credit - i ’m sure he ’ll take all the credit that he wants . ” xxmaj wrong xxmaj bernie , the xxmaj economy is doing xxup great , and would have xxup crashed if my opponent ( and yours ) ,</td>
#       <td>realDonaldTrump</td>
#     </tr>
#     <tr>
#       <td>xxbos @choo_ek @johnlegend @ewarren 1 . xxmaj ability to pass \n  2 . xxmaj ability to fund \n  3 . xxmaj disruption \n  4 . xxmaj timeline \n  5 . xxmaj checks and balances between private and public . xxmaj they have to compete much like xxup ma does with xxmaj medicare but no xxup oop with either allowed \n  5 . xxmaj more funds</td>
#       <td>mcuban</td>
#     </tr>
#     <tr>
# realDonaldTrump,realDonaldTrump,realDonaldTrump,realDonaldTrump,realDonaldTrump
# Path: Tweets;
#
# Valid: LabelList (2439 items)
# x: TextList
# xxbos xxmaj thanks to the historic xxup gop tax cuts , xxmaj americans across the country have seen a booming economy and higher wages . xxmaj this # taxday , i urge my xxmaj democratic colleagues to join us in making the middle - class tax cuts permanent , so that millions of xxmaj american families may continue to prosper .,xxbos xxmaj thank you . xxmaj they are xxup heroes . @dallasmavs will continue to find ways to help those who put themselves at risk to protect us . # xxunk,xxbos xxmaj reeling from xxmaj tuesday ’s shocking election , xxmaj dems try to xxunk health reform :,xxbos xxmaj it is important both to our national and economic security that we have an alternative xxup gps timing system . i am grateful for @senmarkey ’s leadership on this issue , and i am hopeful this bill is swiftly signed into law .,xxbos i ’m glad @johnkingated held firm and finally pulled the plug on for - profit college xxunk xxup acics .
# y: CategoryList
# SenTedCruz,mcuban,MittRomney,SenTedCruz,SenWarren
# Path: Tweets;
#
# Test: None, model=SequentialRNN(
#   (0): MultiBatchEncoder(
#     (module): AWD_LSTM(
#       (encoder): Embedding(20624, 400, padding_idx=1)
#       (encoder_dp): EmbeddingDropout(
#         (emb): Embedding(20624, 400, padding_idx=1)
#       )
#       (rnns): ModuleList(
#         (0): WeightDropout(
#           (module): LSTM(400, 1152, batch_first=True)
#         )
#         (1): WeightDropout(
#           (module): LSTM(1152, 1152, batch_first=True)
#         )
#         (2): WeightDropout(
#           (module): LSTM(1152, 400, batch_first=True)
#         )
#       )
#       (input_dp): RNNDropout()
#       (hidden_dps): ModuleList(
#         (0): RNNDropout()
#         (1): RNNDropout()
#         (2): RNNDropout()
#       )
#     )
#   )
#   (1): PoolingLinearClassifier(
#     (layers): Sequential(
#       (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Dropout(p=0.2, inplace=False)
#       (2): Linear(in_features=1200, out_features=50, bias=True)
#       (3): ReLU(inplace=True)
#       (4): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Dropout(p=0.1, inplace=False)
#       (6): Linear(in_features=50, out_features=10, bias=True)
#     )
#   )
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=FlattenedLoss of CrossEntropyLoss(), metrics=[<function accuracy at 0x7f28c5d7eae8>], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=PosixPath('Tweets'), model_dir='models', callback_fns=[functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True, silent=False)], callbacks=[...], layer_groups=[Sequential(
#   (0): Embedding(20624, 400, padding_idx=1)
#   (1): EmbeddingDropout(
#     (emb): Embedding(20624, 400, padding_idx=1)
#   )
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(400, 1152, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1152, 1152, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1152, 400, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): PoolingLinearClassifier(
#     (layers): Sequential(
#       (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Dropout(p=0.2, inplace=False)
#       (2): Linear(in_features=1200, out_features=50, bias=True)
#       (3): ReLU(inplace=True)
#       (4): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Dropout(p=0.1, inplace=False)
#       (6): Linear(in_features=50, out_features=10, bias=True)
#     )
#   )
# )], add_time=True, silent=False)
# alpha: 2.0
# beta: 1.0], layer_groups=[Sequential(
#   (0): Embedding(20624, 400, padding_idx=1)
#   (1): EmbeddingDropout(
#     (emb): Embedding(20624, 400, padding_idx=1)
#   )
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(400, 1152, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1152, 1152, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1152, 400, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): PoolingLinearClassifier(
#     (layers): Sequential(
#       (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Dropout(p=0.2, inplace=False)
#       (2): Linear(in_features=1200, out_features=50, bias=True)
#       (3): ReLU(inplace=True)
#       (4): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Dropout(p=0.1, inplace=False)
#       (6): Linear(in_features=50, out_features=10, bias=True)
#     )
#   )
# )], add_time=True, silent=False)

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='94' class='' max='457' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       20.57% [94/457 00:03<00:15 3.7583]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(2, slice(1e-3,1e-1), moms=(0.8,0.7))
learn.save('first-large')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.583287</td>
#       <td>1.274221</td>
#       <td>0.565806</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.341525</td>
#       <td>1.104785</td>
#       <td>0.618696</td>
#       <td>00:18</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.freeze_to(-2)
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='88' class='' max='457' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       19.26% [88/457 00:04<00:17 1.7577]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.freeze_to(-2)
learn.fit_one_cycle(1, 1e-3/(2.6**4), moms=(0.8,0.7))
learn.save('second-large')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.279531</td>
#       <td>1.113228</td>
#       <td>0.623206</td>
#       <td>00:21</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.freeze_to(-3)
learn.fit_one_cycle(1, 5e-3/(2.6**4), moms=(0.8,0.7))
learn.save('third')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.255479</td>
#       <td>1.049073</td>
#       <td>0.643296</td>
#       <td>00:37</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.lr_find()
learn.recorder.plot()

# %%
learn.unfreeze()
learn.fit_one_cycle(2, slice(1e-3/(2.6**4),1e-3), moms=(0.8,0.7))
learn.save('fourth-large')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.122548</td>
#       <td>0.940022</td>
#       <td>0.678147</td>
#       <td>00:50</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.064810</td>
#       <td>0.899276</td>
#       <td>0.686347</td>
#       <td>00:44</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.unfreeze()
learn.fit_one_cycle(2, slice(1e-3/(2.6**4),1e-3), moms=(0.8,0.7))
learn.save('fifth-large')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.993825</td>
#       <td>0.819298</td>
#       <td>0.720377</td>
#       <td>00:49</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.889897</td>
#       <td>0.790957</td>
#       <td>0.724067</td>
#       <td>00:50</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.unfreeze()
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='91' class='' max='595' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       15.29% [91/595 00:06<00:35 3.5209]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.unfreeze()
learn.fit_one_cycle(2, slice(1e-3/(2.6**4)), moms=(0.8,0.7))
learn.save('sixth-large')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.035339</td>
#       <td>0.924879</td>
#       <td>0.677054</td>
#       <td>00:40</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.080225</td>
#       <td>0.917747</td>
#       <td>0.684608</td>
#       <td>00:44</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.unfreeze()
learn.fit_one_cycle(2, slice(1e-3/(2.6**4)), moms=(0.8,0.7))
learn.save('seventh-large')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.055498</td>
#       <td>0.913743</td>
#       <td>0.688700</td>
#       <td>00:41</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.066321</td>
#       <td>0.923189</td>
#       <td>0.680201</td>
#       <td>00:42</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.unfreeze()
learn.fit_one_cycle(2, slice(1e-4/(2.6**4)), moms=(0.8,0.7))
learn.save('eighth-large')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.038458</td>
#       <td>0.922547</td>
#       <td>0.683349</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.050278</td>
#       <td>0.919923</td>
#       <td>0.684923</td>
#       <td>00:42</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.unfreeze()
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='90' class='' max='595' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       15.13% [90/595 00:06<00:35 2.4906]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %% [markdown]
# ## Model Evaluation

# %%
interp = TextClassificationInterpretation.from_learner(learn)

# %%
interp.show_top_losses(5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Text</th>
#       <th>Prediction</th>
#       <th>Actual</th>
#       <th>Loss</th>
#       <th>Probability</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>xxbos</td>
#       <td>realDonaldTrump</td>
#       <td>JoeBiden</td>
#       <td>7.17</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos @cnnsotu : xxmaj tomorrow on # xxup cnnsotu w / @jaketapper : @senatorromney and xxunk !</td>
#       <td>BernieSanders</td>
#       <td>SenatorRomney</td>
#       <td>6.81</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj it is good news that the xxmaj special xxmaj counsel has concluded that neither the xxmaj president nor his campaign xxunk with the xxmaj russian government . xxmaj it is now time for the country to move forward .</td>
#       <td>SenKamalaHarris</td>
#       <td>SenatorRomney</td>
#       <td>6.10</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos</td>
#       <td>realDonaldTrump</td>
#       <td>SenWarren</td>
#       <td>5.97</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj this is pathetic .</td>
#       <td>SenKamalaHarris</td>
#       <td>SenTedCruz</td>
#       <td>5.96</td>
#       <td>0.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
interp.show_intrinsic_attention("Immigration is the driving force behind America!")
# Out:
# /pytorch/aten/src/ATen/native/cuda/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# /pytorch/aten/src/ATen/native/cuda/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# <span style="font-family: monospace;"><span title="0.333" style="background-color: rgba(253, 190, 110, 0.5);">xxbos</span> <span title="0.517" style="background-color: rgba(248, 252, 181, 0.5);">xxmaj</span> <span title="1.000" style="background-color: rgba(0, 104, 55, 0.5);">immigration</span> <span title="0.569" style="background-color: rgba(228, 244, 155, 0.5);">is</span> <span title="0.629" style="background-color: rgba(203, 232, 129, 0.5);">the</span> <span title="0.785" style="background-color: rgba(112, 193, 100, 0.5);">driving</span> <span title="0.662" style="background-color: rgba(185, 225, 118, 0.5);">force</span> <span title="0.590" style="background-color: rgba(219, 240, 143, 0.5);">behind</span> <span title="0.588" style="background-color: rgba(221, 240, 145, 0.5);">xxmaj</span> <span title="0.830" style="background-color: rgba(78, 177, 93, 0.5);">america</span> <span title="0.741" style="background-color: rgba(139, 205, 103, 0.5);">!</span></span>

# %%
interp.plot_confusion_matrix()

# %%
list(learn.model.parameters())
# Out:
# [Parameter containing:
#  tensor([[-0.1353,  0.4438, -0.2424,  ..., -0.2903,  1.0681,  1.1670],
#          [ 0.1959, -0.0158,  0.0056,  ..., -0.0604,  0.2325, -0.0146],
#          [ 0.2755,  0.9498,  1.7809,  ..., -0.3519, -1.6625,  0.3028],
#          ...,
#          [ 0.2872, -0.0424,  0.0107,  ..., -0.2341,  0.4312, -0.0449],
#          [ 0.2872, -0.0424,  0.0107,  ..., -0.2341,  0.4312, -0.0449],
#          [ 0.2872, -0.0424,  0.0107,  ..., -0.2341,  0.4312, -0.0449]],
#         device='cuda:0', requires_grad=True), Parameter containing:
#  tensor([[ 0.0635, -0.0177, -0.0846,  ..., -0.0891, -0.0677, -0.0371],
#          [-0.0577, -0.0480,  0.0155,  ...,  0.1863, -0.1118,  0.0776],
#          [ 0.2037, -0.0169,  0.2719,  ...,  0.0470,  0.0594,  0.0120],
#          ...,
#          [-0.1064,  0.1952,  0.0993,  ..., -0.1411,  0.0134, -0.0083],
#          [-0.0510, -0.0786,  0.0363,  ..., -0.1817, -0.0127,  0.0603],
#          [ 0.0097,  0.0546,  0.0012,  ...,  0.0302,  0.1304,  0.0362]],
#         device='cuda:0', requires_grad=True), Parameter containing:
#  tensor
#           -4.6764e-01, -2.6998e-01,  1.7945e-01, -5.5005e-01, -3.2439e-01,
#           -5.4883e-01,  6.2872e-01, -7.1841e-01,  1.4561e-01, -8.6418e-02]],
#         device='cuda:0', requires_grad=True), Parameter containing:
#  tensor([ 0.3198,  0.0568,  0.1543,  0.5139,  0.2856,  0.5301, -1.2569, -1.5210,
#           0.3108, -0.4204], device='cuda:0', requires_grad=True)]

# %%
learn.summary()
# Out:
# SequentialRNN
# ======================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ======================================================================
# RNNDropout           [25, 400]            0          False
# ______________________________________________________________________
# RNNDropout           [25, 1152]           0          False
# ______________________________________________________________________
# RNNDropout           [25, 1152]           0          False
# ______________________________________________________________________
# BatchNorm1d          [1200]               2,400      True
# ______________________________________________________________________
# Dropout              [1200]               0          False
# ______________________________________________________________________
# Linear               [50]                 60,050     True
# ______________________________________________________________________
# ReLU                 [50]                 0          False
# ______________________________________________________________________
# BatchNorm1d          [50]                 100        True
# ______________________________________________________________________
# Dropout              [50]                 0          False
# ______________________________________________________________________
# Linear               [10]                 510        True
# ______________________________________________________________________
#
# Total params: 63,060
# Total trainable params: 63,060
# Total non-trainable params: 0
# Optimized with 'torch.optim.adam.Adam', betas=(0.9, 0.99)
# Using true weight decay as discussed in https://www.fast.ai/2018/07/02/adam-weight-decay/
# Loss function : FlattenedLoss
# ======================================================================
# Callbacks functions applied
#     RNNTrainer

# %%
p = np.matrix(list(learn.model.parameters())[-2].cpu().detach().numpy())

# %%
targets = pd.Series(["BernieSanders", "JoeBiden", "MittRomney", "SenKamalaHarris", "SenTedCruz", "SenWarren", "SenatorRomney", "mcuban", "mike_pence", "realDonaldTrump"], name = 'targets')
finalDf = pd.concat([principalDf, targets], axis = 1)
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
for target in targets:
    indicesToKeep = finalDf['targets'] == target
    ax.scatter(finalDf.loc[indicesToKeep, 'principal component 1']
               , finalDf.loc[indicesToKeep, 'principal component 2']
               , s = 50)
ax.legend(targets)
ax.grid()

# %%
principalDf
# Out:
#    principal component 1  principal component 2
# 0              -1.589650              -0.175766
# 1              -1.499155              -0.617511
# 2              -0.766999              -0.339272
# 3              -0.828203               0.216285
# 4               1.251137              -0.576669
# 5              -0.310466              -0.082849
# 6               1.875615              -0.849427
# 7               0.468387               3.110376
# 8               0.590278              -0.458011
# 9               0.809056              -0.227155

# %%
finalDf
# Out:
#    principal component 1  principal component 2                0
# 0              -1.589650              -0.175766    BernieSanders
# 1              -1.499155              -0.617511         JoeBiden
# 2              -0.766999              -0.339272       MittRomney
# 3              -0.828203               0.216285  SenKamalaHarris
# 4               1.251137              -0.576669       SenTedCruz
# 5              -0.310466              -0.082849        SenWarren
# 6               1.875615              -0.849427    SenatorRomney
# 7               0.468387               3.110376           mcuban
# 8               0.590278              -0.458011       mike_pence
# 9               0.809056              -0.227155  realDonaldTrump

# %%
learn.summary()
# Out:
# SequentialRNN
# ======================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ======================================================================
# RNNDropout           [25, 400]            0          False
# ______________________________________________________________________
# RNNDropout           [25, 1152]           0          False
# ______________________________________________________________________
# RNNDropout           [25, 1152]           0          False
# ______________________________________________________________________
# BatchNorm1d          [1200]               2,400      True
# ______________________________________________________________________
# Dropout              [1200]               0          False
# ______________________________________________________________________
# Linear               [50]                 60,050     True
# ______________________________________________________________________
# ReLU                 [50]                 0          False
# ______________________________________________________________________
# BatchNorm1d          [50]                 100        True
# ______________________________________________________________________
# Dropout              [50]                 0          False
# ______________________________________________________________________
# Linear               [10]                 510        True
# ______________________________________________________________________
#
# Total params: 63,060
# Total trainable params: 63,060
# Total non-trainable params: 0
# Optimized with 'torch.optim.adam.Adam', betas=(0.9, 0.99)
# Using true weight decay as discussed in https://www.fast.ai/2018/07/02/adam-weight-decay/
# Loss function : FlattenedLoss
# ======================================================================
# Callbacks functions applied
#     RNNTrainer

# %%
learn.model.parameters
# Out:
# <bound method Module.parameters of SequentialRNN(
#   (0): MultiBatchEncoder(
#     (module): AWD_LSTM(
#       (encoder): Embedding(20624, 400, padding_idx=1)
#       (encoder_dp): EmbeddingDropout(
#         (emb): Embedding(20624, 400, padding_idx=1)
#       )
#       (rnns): ModuleList(
#         (0): WeightDropout(
#           (module): LSTM(400, 1152, batch_first=True)
#         )
#         (1): WeightDropout(
#           (module): LSTM(1152, 1152, batch_first=True)
#         )
#         (2): WeightDropout(
#           (module): LSTM(1152, 400, batch_first=True)
#         )
#       )
#       (input_dp): RNNDropout()
#       (hidden_dps): ModuleList(
#         (0): RNNDropout()
#         (1): RNNDropout()
#         (2): RNNDropout()
#       )
#     )
#   )
#   (1): PoolingLinearClassifier(
#     (layers): Sequential(
#       (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Dropout(p=0.2, inplace=False)
#       (2): Linear(in_features=1200, out_features=50, bias=True)
#       (3): ReLU(inplace=True)
#       (4): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Dropout(p=0.1, inplace=False)
#       (6): Linear(in_features=50, out_features=10, bias=True)
#     )
#   )
# )>

# %%
################### Further Development for Topic-based data filteration ########################

# %%
def word_in_text(word, text):
    word = word.lower()
    text = text.lower()
    match = re.search(word, text)
    if match:
        return True
    return False

def word_basket_in_text(word_list, text):
    status = True
    for word in word_list:
        if type(word)==list:
            list_status = False
            for list_word in word:
                list_status = list_status or word_in_text(list_word, text)
            status = status and list_status
        else: status = status and word_in_text(word, text)
    return status

# %%
# Changing &amp; to 'and'
tweets.text = tweets.text.apply(lambda x: re.sub(u'\&amp\;', u'and', x))

# extracting URLS
tweets['urls'] = tweets.text.apply(lambda x: re.findall('http\S+', x))
tweets['text_clean'] = tweets.text.apply(lambda x: re.sub(u'http\S+', u'', x)) 

# extracting @... 
tweets['mentions'] = tweets.text.apply(lambda x: re.findall(u'@(\w+)', x))

# extracting hashtags
tweets['hashtags'] = tweets.text.apply(lambda x: re.findall(u'#(\w+)', x))
tweets.text_clean = tweets.text_clean.apply(lambda x: re.sub(u'#', u'', x))

# Binary for Re-Tweets
tweets['retweet'] = tweets.text.apply(lambda x: 1 if len(re.findall(u'RT', x))>0 else 0)
tweets.text_clean = tweets.text_clean.apply(lambda x: re.sub(u'RT', u'', x))

# %%
Healthcare = [u'care','affordable care act', u'medicare', u'obamacare',  u'benefits', u'opioid', u'abortion', u'medicaid', u'single payer', u'medication', u'prescription', u'drugs', u'hospital', u'health', u'care']
Terrorism = [u'al', u'terror', u'sanctions', u'drone', u'oil', u'gulf', u'intelligence', u'ISIS', u'military', u'nuclear']
Economy = [u'china', u'tariff', u'mexico', u'fed', u'sec', u'interest', u'rate', u'immigration', u'debt', u'unemployment', u'growth', u'inflation', u'trade war', u'dollar', u'gdp', u'g20', u'recession', u'stock', u'market']
lgbtq = [u'gay', u'lesbian', u'pride', u'community', u'lgbt', u'same-sex', u'marriage', u'orientation', u'parade', u'stonewall', u'riot', u'civil', u'homosexual', u'queer', u'conversion']

china_tariffs = ['china', 'tariff']
safe_abortion = ['abortion', ['safe', 'legal']]
abortion_ban = ['abortion', ['ban', 'restrictions', 'extreme']]
affordable_care = ['health', ['affordable', 'obamacare', 'medicare', 'care']]
medicare = ['MedicareForAll', ['Medicare']] 
greennewdeal = ['greennewdeal']
lgbtq_marriage_equality_act = [['marriage', 'relationship', 'relationships', 'couple', 'couples'], ['gay', 'lesbian', 'pride', 'orientation']]

# %%
# Final List

# Healthcare
affordable_care = ['health', ['affordable', 'obamacare', 'medicare', 'care']]
medicare = ['medicare'] 
safe_abortion = ['abortion', ['safe', 'legal']]
abortion_ban = ['abortion', ['ban', 'restrictions', 'extreme']]

# Education
education_for_all = ['education', ['afford', 'free']]
student_loans = ['student', ['cancel', 'loans', 'debt']]

# Immigration
immigration = ['immigration', ['policy', 'policies', 'mexico', 'illegal', 'undocumented', 'border']]
asylum = ['border', ['detention', 'families', 'family', 'asylum']]

# Guns
Gun_Laws = ['gun', ['semi-automatic', 'assault', 'shooting', 'reform', 'open carry', 'second amendment']]

#Climate
Global_Warming = ['climate', ['global warming', 'emissions', 'pollution', 'accord', 'fossil', 'fuel', 'oil']]
GND = [['net-zero', 'net zero', 'carbon', 'green']]

# %%
all_tweets = ''
for tweet in tweets['text']:
    if word_basket_in_text(GND, tweet):
        print('-------')
        tweet = re.sub(u'\&amp\;', u'and', tweet)
        tweet = re.sub(u'http\S+', u'', tweet)
        tweet = re.sub(u'@(\w+)', u'', tweet)   
        tweet = re.sub(u'-', u' ', tweet) 
        print(tweet)
        all_tweets = all_tweets + ' ; ' + tweet
# Out:
# -------
# RT : We must take bold action on climate change and create a green economy that benefits all Americans. Thank you to …
# -------
# RT : In NJ driving on the Turnpike with my State Director  (and his green tie) this morning—heading to a great round tabl…
# -------
# RT : Bob Menendez is a champion for protecting New Jersey’s beaches, coastal communities and green spaces. Today, Bob joined wi…
# -------
# RT : Our most vulnerable communities are disproportionately impacted by pollution + hit first and worst by climate change. Learn…
# -------
#                                                 61. Green Latinos  opposes the Senate  health care bill
# -------
#                                                 60. Green For All  opposes the Senate  health care bill

# %%
tknzr = TweetTokenizer()
counts = Counter(tknzr.tokenize(all_tweets))
print(counts)
# Out:
# Counter({'the': 45, 'and': 35, '.': 34, 'our': 26, ',': 25, 'border': 25, 'to': 23, 'of': 22, ';': 21, 'immigration': 20, 'a': 15, 'I': 12, 'at': 8, 'illegal': 8, 'in': 8, 'have': 7, 'that': 7, 'wall': 7, '’': 6, 'as': 6, 'The': 6, ':': 6, 'southern': 6, 'crisis': 6, 'for': 6, 'country': 6, 'an': 5, 'want': 5, 'see': 5, 'is': 5, 'broken': 5, 'system': 5, 'secure': 5, 'people': 5, 'Texans': 4, 'agents': 4, 'human': 4, 'children': 4, 'today': 4, 'by': 4, 'humanitarian': 4, 'we': 4, 'We': 4, 'called': 4, 'building': 4, 'necessary': 4, 'step': 4, 'stopping': 4, 'flow': 4, 'into': 4, 'defending': 4, 'overwhelming': 3, 'majority': 3, 'they': 3, 'secured': 3, 'Border': 3, 'Patrol': 3, 'legal': 3, '#SecureTheBorder': 3, 'has': 3, 'security': 3, 'must': 3, 'need': 3, 'put': 3, 'catch': 3, 'release': 3, 'which': 3, 'on': 3, '>': 3, 'long': 3, 's': 3, 'who': 3, 'American': 3, 'are': 3, 'Texas': 2, 'supported': 2, 'championed': 2, 'traffickers': 2, 'drug': 2, 'produced': 2, 'RT': 2, 'A': 2, 'exists': 2, 'because': 2, 'end': 2, 'harm': 2, '…': 2, 'practices': 2, 'like': 2, "'": 2, 'questioned': 2, 'build': 2, 'occurring': 2, 'securing': 2, 'families': 2, 'tragedies': 2, 'not': 2, 'smuggling': 2, 'being': 2, 'abused': 2, 'us': 2, 'face': 2, 'illegally': 2, 'ICE': 2, 'enter': 2, 'also': 2, 'policy': 2, 'judges': 2, 'asylum': 2, 'cases': 2, 'As': 1, 've': 1, 'traveled': 1, 'across': 1, 'expressed': 1, 'There': 1, 'no': 1, 'denying': 1, 'result': 1, 'Congressional': 1, 'inaction': 1, 'crimin